# %%
import pandas as pd
import os
import base64
import requests
from time import sleep
import matplotlib.pyplot as plt

# %% [markdown]
# ## Twitter dataset preparation for labeling

# %% [markdown]
# ### 1. Importing cleaned csv

# %%
tweets_df = pd.read_csv('cleaned_elderly_tweets.csv')

# %%
tweets_df.head()
# Out:
#    Unnamed: 0                 date_time             tweet_id  \
# 0           0  2022-02-24T21:33:19.000Z  1496961461465542656
# 1           1  2022-02-24T20:28:33.000Z  1496945165365219333
# 2           2  2022-02-24T20:25:13.000Z  1496944326416510984
# 3           3  2022-02-24T19:44:18.000Z  1496934029542793224
# 4           4  2022-02-24T18:53:50.000Z  1496921328103804935
#
#              author_id          place_id  \
# 0           3240659214  38d5974e82ed1a6c
# 1  1469167464101515267  0811cf61cd9ea52f
# 2           3355188729  3797791ff9c0e4c6
# 3             21305650  3797791ff9c0e4c6
# 4             50382485  71bdc845bc7609c7
#
#                                           tweet_text  \
# 0  @JosephConwell7 @Reuters I live here &amp; the...
# 1  Winnipeg seniors, wya?!! \nI’m doing Mini sess...
# 2  This is no joke. I have gone to several stores...
# 3  @cllrainslie Vaccines are great for the elderl...
# 4  Be part of the movement from hallway care to h...
#
#                                         cleaned_text  \
# 0  I live here and these far right bully boys pic...
# 1  Winnipeg seniors, wya?!! Im doing Mini session...
# 2  This is no joke. I have gone to several stores...
# 3  Vaccines are great for the elderly and / or th...
# 4  Be part of the movement from hallway care to h...
#
#                       hashtags
# 0                           []
# 1  ['winnipeg', 'collegegrad']
# 2                           []
# 3                           []
# 4  ['Woodstock', 'Healthcare']

# %% [markdown]
# ### 2. Gathering location name from place_id variables

# %%
places = tweets_df['place_id'].value_counts()
places
# Out:
# 3797791ff9c0e4c6    9197
# 38d5974e82ed1a6c    3222
# 53504716d445dcad    2926
# 6a6d896ba1cb5dc4    2791
# 1e5cb4d0509db554    2685
#                     ...
# 209726d85549d2d5       1
# 2b283eb6bc155115       1
# 73fe89382cabbe53       1
# 532b2c07da89e14d       1
# 07d9db50c2080001       1
# Name: place_id, Length: 2987, dtype: int64

# %%
places_ids = list(places.index)
places_ids[:10]
# Out:
# ['3797791ff9c0e4c6',
#  '38d5974e82ed1a6c',
#  '53504716d445dcad',
#  '6a6d896ba1cb5dc4',
#  '1e5cb4d0509db554',
#  '0811cf61cd9ea52f',
#  '5c43cbdfce4d3247',
#  '5d058f2e9fe1516c',
#  '4939b600461c30a4',
#  '36775d842cbec509']

# %%
# Setting bearer token as an environment variable
# os.environ['API_KEY'] = "<API_KEY>"
# os.environ['API_SECRET_KEY'] = "<API_SECRET_KEY>"

# %%
# Request for tweets place_id information

# Reformat the keys and encode
key_secret = '{}:{}'.format(os.environ['API_KEY'], os.environ['API_SECRET_KEY']).encode('ascii')

# Transform from bytes to bytes that can be printed
b64_encoded_key = base64.b64encode(key_secret)

# Transform from bytes back into Unicode
b64_encoded_key = b64_encoded_key.decode('ascii')

# Posting authentication request using Twitter authentication resource URL
base_url = 'https://api.twitter.com/'
auth_url = '{}oauth2/token'.format(base_url)
auth_headers = {
    'Authorization': 'Basic {}'.format(b64_encoded_key),
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
}
auth_data = {
    'grant_type': 'client_credentials'
}
auth_resp = requests.post(auth_url, headers = auth_headers, data = auth_data)
print(auth_resp.status_code)
access_token = auth_resp.json()['access_token']
# Out:
# 200

# %%
# Storing access_token as an OS environment variable
os.environ['ACCESS_TOKEN'] = access_token

# %%
def getLocation(id):
    '''
    Arguments:
    id -- string. Place id.

    Returns:
    place_name -- string. Full_name of place returned from the geo_localization id GET request.
    '''
    try:
      os.environ['ACCESS_TOKEN']
    except:
      print('Access token not found under <"ACCESS_TOKEN"> OS Environment variable.')
    else:
      access_token = os.environ['ACCESS_TOKEN']

    # Creating headers
    geo_headers = {
    'Authorization': 'Bearer {}'.format(access_token)    
    }

    # Building url
    geo_url = f'https://api.twitter.com/1.1/geo/id/{id}.json'
    geo_resp = requests.get(geo_url, headers = geo_headers)

    if geo_resp.status_code != 200:
        print(f'Failed request. {geo_resp.text}')
        place_name = ''
    else:
        place_name = geo_resp.json()['full_name']
        print(f'Request successful. Place name {place_name} returned for place_id {id}.')

    return place_name

# %%
places = {}
places['place_id'] = places_ids
places['place_name'] = []

request_counter = 0
for n, place_id in enumerate(places_ids):
    if request_counter < 99:
        print(f'{n+1}: place_id {place_id}')
        places['place_name'].append(getLocation(place_id))
        request_counter += 1
    else:
        print(f'{n+1}: place_id {place_id}')
        places['place_name'].append(getLocation(place_id))
        print('100 requests limit reached. Sleeping for 15 minutes...')
        sleep(910)
        print('Resuming requests...')
        request_counter = 0
# Out:
# 1: place_id 3797791ff9c0e4c6
# Request successful. Place name Toronto, Ontario returned for place_id 3797791ff9c0e4c6.
# 2: place_id 38d5974e82ed1a6c
# Request successful. Place name Ottawa, Ontario returned for place_id 38d5974e82ed1a6c.
# 3: place_id 53504716d445dcad
# Request successful. Place name Calgary, Alberta returned for place_id 53504716d445dcad.
# 4: place_id 6a6d896ba1cb5dc4
# Request successful. Place name Edmonton, Alberta returned for place_id 6a6d896ba1cb5dc4.
# 5: place_id 1e5cb4d0509db554
# Request successful. Place name Vancouver, British Columbia returned for place_id 1e5cb4d0509db554.
# 6: place_id 0811cf61cd9ea52f
# Request successful. Place name Winnipeg, Manitoba returned for place_id 0811cf61cd9ea52f.
# 7: place_id 5c43cbdfce4d3247
# Request successful. Place name Mississauga, Ontario returned for place_id 5c43cbdfce4d3247.
# 8: place_id 5d058f2e9fe1516c
# Request successful. Place name Halifax, Nova Scotia returned for place_id 5d058f2e9fe1516c.
# 9: place_id 4939b600461c30a4
# Request successful. Place name Hamilton, Ontario returned for place_id 4939b600461c30a4.
# 10: place_id 36775d842cbec509
# Request successful. Place name Montréal, Québec returned for place_id 36775d842cbec509.
# 11: place_id 1f4df2b4746ddea7
# Request successful. Place name Brampton, Ontario returned for place_id 1f4df2b4746ddea7.
# 12: place_id 1795f2e3639cab31
# Request successful. Place name London, Ontario returned for place_id 1795f2e3639cab31.
# 13: place_id 09efd2065c8ce28e
# Request successful. Place name Surrey, British Columbia returned for place_id 09efd2065c8ce28e.
# 14: place_id 2c1be03622fe39b8
# Request successful. Place name Regina, Saskatchewan returned for place_id 2c1be03622fe39b8.
# 15: place_id 6faccdedef66864c
# Request successful. Place name St. John's, Newfoundland and Labrador returned for place_id 6faccdedef66864c.
# 16: place_id 78d9392bd6093265
# Request successful. Place name Vaughan, Ontario returned for place_id 78d9392bd6093265.
# 17: place_id 4fdbcad8c3ed7790
# Request successful. Place name Victoria, British Columbia returned for place_id 4fdbcad8c3ed7790.
# 18: place_id 7059f9b9f31d4c4a
# Request successful. Place name Burlington, Ontario returned for place_id 7059f9b9f31d4c4a.
# 19: place_id 47be6341b02ac59f
# Request successful. Place name Kitchener, Ontario returned for place_id 47be6341b02ac59f.
# 20: place_id 48ad377ff2ff9e51
# Request successful. Place name Kingston, Ontario returned for place_id 48ad377ff2ff9e51.
# 21: place_id 5147516179fa9c13
# Request successful. Place name Burnaby, British Columbia returned for place_id 5147516179fa9c13.
# 22: place_id 4bb41f9d86e16416
# Request successful. Place name Saskatoon, Saskatchewan returned for place_id 4bb41f9d86e16416.
# 23: place_id 79a60b51078a624f
# Request successful. Place name Strathcona County, Alberta returned for place_id 79a60b51078a624f.
# 24: place_id 15b0a643e7bd22c7
# Request successful. Place name Windsor, Ontario returned for place_id 15b0a643e7bd22c7.
# 25: place_id 2740624a2d391c5c
# Request successful. Place name Guelph, Ontario returned for place_id 2740624a2d391c5c.
# 26: place_id 33ad9818da34b8ec
# Request successful. Place name Waterloo, Ontario returned for place_id 33ad9818da34b8ec.
# 27: place_id 216dd1bcf824f9f7
# Request successful. Place name Greater Vancouver, British Columbia returned for place_id 216dd1bcf824f9f7.
# 28: place_id 7d2673c3623fe492
# Request successful. Place name Markham, Ontario returned for place_id 7d2673c3623fe492.
# 29: place_id 146b4e4e831313bb
# Request successful. Place name Whitby, Ontario returned for place_id 146b4e4e831313bb.
# 30: place_id 3100dc510186d8b6
# Request successful. Place name Richmond, British Columbia returned for place_id 3100dc510186d8b6.
# 31: place_id 61ecf520fef6ce72
# Request successful. Place name Oakville, Ontario returned for place_id 61ecf520fef6ce72.
# 32: place_id 2615344c84ed87ee
# Request successful. Place name Oshawa, Ontario returned for place_id 2615344c84ed87ee.
# 33: place_id 04c219a0705982cf
# Request successful. Place name Ajax, Ontario returned for place_id 04c219a0705982cf.
# 34: place_id 370e82cb8dff6189
# Request successful. Place name Mascouche, Québec returned for place_id 370e82cb8dff6189.
# 35: place_id 2e25bfbedbc62328
# Request successful. Place name St. Catharines, Ontario returned for place_id 2e25bfbedbc62328.
# 36: place_id 11ec8106d4d1a9a4
# Request successful. Place name Barrie, Ontario returned for place_id 11ec8106d4d1a9a4.
# 37: place_id 32bdf27d67a9570d
# Request successful. Place name Peterborough, Ontario returned for place_id 32bdf27d67a9570d.
# 38: place_id 1bbb3bca095cc945
# Request successful. Place name Nanaimo, British Columbia returned for place_id 1bbb3bca095cc945.
# 39: place_id 33de55bc584a42ec
# Request successful. Place name New Westminster, British Columbia returned for place_id 33de55bc584a42ec.
# 40: place_id 34e47ddf52a690bc
# Request successful. Place name Richmond Hill, Ontario returned for place_id 34e47ddf52a690bc.
# 41: place_id 52bc3157f597168a
# Request successful. Place name Saanich, British Columbia returned for place_id 52bc3157f597168a.
# 42: place_id 125a714e2a35da7d
# Request successful. Place name Niagara Falls, Ontario returned for place_id 125a714e2a35da7d.
# 43: place_id 484de3636fa22d62
# Request successful. Place name Kelowna, British Columbia returned for place_id 484de3636fa22d62.
# 44: place_id 2b78ee9f58b991a8
# Request successful. Place name North Vancouver, British Columbia returned for place_id 2b78ee9f58b991a8.
# 45: place_id 3376992a082d67c7
# Request successful. Place name Canada returned for place_id 3376992a082d67c7.
# 46: place_id 4b3d1118aaf39b1f
# Request successful. Place name Charlottetown, Prince Edward Island returned for place_id 4b3d1118aaf39b1f.
# 47: place_id 435a15a8bf629083
# Request successful. Place name Coquitlam, British Columbia returned for place_id 435a15a8bf629083.
# 48: place_id 5346c2e28722a421
# Request successful. Place name Cape Breton, Nova Scotia returned for place_id 5346c2e28722a421.
# 49: place_id 5f102b4a7cc3d42e
# Request successful. Place name Greater Sudbury / Grand Sudbury, Ontario returned for place_id 5f102b4a7cc3d42e.
# 50: place_id 55b2935da16ddb91
# Request successful. Place name Port Moody, British Columbia returned for place_id 55b2935da16ddb91.
# 51: place_id 246439ffd8801ae2
# Request successful. Place name Red Deer, Alberta returned for place_id 246439ffd8801ae2.
# 52: place_id 550393b2ef425bbb
# Request successful. Place name Chatham-Kent, Ontario returned for place_id 550393b2ef425bbb.
# 53: place_id 349f43f819b079b9
# Request successful. Place name Fredericton, New Brunswick returned for place_id 349f43f819b079b9.
# 54: place_id 5f49a5792faa1e89
# Request successful. Place name Delta, British Columbia returned for place_id 5f49a5792faa1e89.
# 55: place_id 7f26a3e661069882
# Request successful. Place name Saint John, New Brunswick returned for place_id 7f26a3e661069882.
# 56: place_id 71ae4593b0caefd3
# Request successful. Place name North Vancouver, British Columbia returned for place_id 71ae4593b0caefd3.
# 57: place_id 684b2b4e552bfa08
# Request successful. Place name Lethbridge, Alberta returned for place_id 684b2b4e552bfa08.
# 58: place_id 1c4923a87ae4f277
# Request successful. Place name Clarington, Ontario returned for place_id 1c4923a87ae4f277.
# 59: place_id 4f0206a4181479ef
# Request successful. Place name Thunder Bay, Ontario returned for place_id 4f0206a4181479ef.
# 60: place_id 353c22ab906632de
# Request successful. Place name Cambridge, Ontario returned for place_id 353c22ab906632de.
# 61: place_id 127021a2772dbff7
# Request successful. Place name Gatineau, Québec returned for place_id 127021a2772dbff7.
# 62: place_id 0019d14b5c4af1de
# Request successful. Place name Yellowknife, Northwest Territories returned for place_id 0019d14b5c4af1de.
# 63: place_id 5a12d334a05c077c
# Request successful. Place name Chilliwack, British Columbia returned for place_id 5a12d334a05c077c.
# 64: place_id 00ccf965e713a598
# Request successful. Place name Kamloops, British Columbia returned for place_id 00ccf965e713a598.
# 65: place_id 1f4902dd49ed392e
# Request successful. Place name Halton Hills, Ontario returned for place_id 1f4902dd49ed392e.
# 66: place_id 5572be96e7fdec45
# Request successful. Place name Pickering, Ontario returned for place_id 5572be96e7fdec45.
# 67: place_id 4348e95318fc29ad
# Request successful. Place name Riverview, New Brunswick returned for place_id 4348e95318fc29ad.
# 68: place_id 0582c884a3ab504d
# Request successful. Place name Prince George, British Columbia returned for place_id 0582c884a3ab504d.
# 69: place_id 2eb22037045b3689
# Request successful. Place name Abbotsford, British Columbia returned for place_id 2eb22037045b3689.
# 70: place_id 77b6118e9dabd504
# Request successful. Place name Milton, Ontario returned for place_id 77b6118e9dabd504.
# 71: place_id 0c0ce98895ab0421
# Request successful. Place name Mount Pearl, Newfoundland and Labrador returned for place_id 0c0ce98895ab0421.
# 72: place_id 5ffe08989f86e151
# Request successful. Place name Newmarket, Ontario returned for place_id 5ffe08989f86e151.
# 73: place_id 56316c24480c1a3a
# Request successful. Place name St. Albert, Alberta returned for place_id 56316c24480c1a3a.
# 74: place_id 7fff23f525878eac
# Request successful. Place name Iqaluit, Nunavut returned for place_id 7fff23f525878eac.
# 75: place_id 5c1e7fef3a713041
# Request successful. Place name Timmins, Ontario returned for place_id 5c1e7fef3a713041.
# 76: place_id 1534d657c4200ea4
# Request successful. Place name Aurora, Ontario returned for place_id 1534d657c4200ea4.
# 77: place_id 1d68da80ca90416d
# Request successful. Place name Kawartha Lakes, Ontario returned for place_id 1d68da80ca90416d.
# 78: place_id 30904a009a9000a0
# Request successful. Place name Central Saanich, British Columbia returned for place_id 30904a009a9000a0.
# 79: place_id 43dab8343fafc800
# Request successful. Place name West Vancouver, British Columbia returned for place_id 43dab8343fafc800.
# 80: place_id 46cfc7fda28c4d88
# Request successful. Place name Airdrie, Alberta returned for place_id 46cfc7fda28c4d88.
# 81: place_id 720203917834b5e6
# Request successful. Place name New Glasgow, Nova Scotia returned for place_id 720203917834b5e6.
# 82: place_id 415241898ab28fce
# Request successful. Place name Moncton, New Brunswick returned for place_id 415241898ab28fce.
# 83: place_id 63e830af2950007d
# Request successful. Place name Sechelt, British Columbia returned for place_id 63e830af2950007d.
# 84: place_id 0a17baca7eb1caad
# Request successful. Place name Wood Buffalo, Alberta returned for place_id 0a17baca7eb1caad.
# 85: place_id 5091952007530306
# Request successful. Place name Castlegar, British Columbia returned for place_id 5091952007530306.
# 86: place_id 626695e48d21858b
# Request successful. Place name Brandon, Manitoba returned for place_id 626695e48d21858b.
# 87: place_id 0112f4ecb6b7afa6
# Request successful. Place name Orangeville, Ontario returned for place_id 0112f4ecb6b7afa6.
# 88: place_id 239d14ba103976d5
# Request successful. Place name Greater Vancouver A, British Columbia returned for place_id 239d14ba103976d5.
# 89: place_id 36fa519a22e202fb
# Request successful. Place name Hope, British Columbia returned for place_id 36fa519a22e202fb.
# 90: place_id 5b7b053903f56c57
# Request successful. Place name Cobourg, Ontario returned for place_id 5b7b053903f56c57.
# 91: place_id 00dc41d1ef797d1a
# Request successful. Place name Moose Jaw, Saskatchewan returned for place_id 00dc41d1ef797d1a.
# 92: place_id 23b629b33fba1676
# Request successful. Place name Québec, Canada returned for place_id 23b629b33fba1676.
# 93: place_id 13e80e6f3ac67066
# Request successful. Place name Maple Ridge, British Columbia returned for place_id 13e80e6f3ac67066.
# 94: place_id 0e9966c128992fda
# Request successful. Place name Canmore, Alberta returned for place_id 0e9966c128992fda.
# 95: place_id 607f11608565d341
# Request successful. Place name Brantford, Ontario returned for place_id 607f11608565d341.
# 96: place_id 62b78f4b441b9a2f
# Request successful. Place name Varennes, Québec returned for place_id 62b78f4b441b9a2f.
# 97: place_id 11715f74895344af
# Request successful. Place name New Tecumseth, Ontario returned for place_id 11715f74895344af.
# 98: place_id 2d6eed0be3fe5d4e
# Request successful. Place name Whitehorse, Yukon returned for place_id 2d6eed0be3fe5d4e.
# 99: place_id 006524497bafd74f
# Request successful. Place name Fort Saskatchewan, Alberta returned for place_id 006524497bafd74f.
# 100: place_id 4a6072604f039cf7
# Request successful. Place name Truro, Nova Scotia returned for place_id 4a6072604f039cf7.
# 100 requests limit reached. Sleeping for 15 minutes...
# Resuming requests...
# 101: place_id 0bdcca7f6f1a86c6
# Request successful. Place name Medicine Hat, Alberta returned for place_id 0bdcca7f6f1a86c6.
# 102: place_id 099d9c46b8f88496
# Request successful. Place name Rocky Mountain House, Alberta returned for place_id 099d9c46b8f88496.
# 103: place_id 71bdc845bc7609c7
# Request successful. Place name Woodstock, Ontario returned for place_id 71bdc845bc7609c7.
# 104: place_id 7df47734553245da
# Request successful. Place name Georgina, Ontario returned for place_id 7df47734553245da.
# 105: place_id 25bfadc376e8c616
# Request successful. Place name Caledon, Ontario returned for place_id 25bfadc376e8c616.
# 106: place_id 083c2dd19042ef42
# Request successful. Place name Conception Bay South, Newfoundland and Labrador returned for place_id 083c2dd19042ef42.
# 107: place_id 6b297b6cc01bdffa
# Request successful. Place name Stony Plain, Alberta returned for place_id 6b297b6cc01bdffa.
# 108: place_id 45050c66e7c3f027
# Request successful. Place name Belleville, Ontario returned for place_id 45050c66e7c3f027.
# 109: place_id 0fc8c757b8967169
# Request successful. Place name St. Thomas, Ontario returned for place_id 0fc8c757b8967169.
# 110: place_id 4f672cd7242154dc
# Request successful. Place name Sault Ste. Marie, Ontario returned for place_id 4f672cd7242154dc.
# 111: place_id 123b009a7b58211d
# Request successful. Place name Orillia, Ontario returned for place_id 123b009a7b58211d.
# 112: place_id 6a06dc5ecb2a02ef
# Request successful. Place name Lanark Highlands, Ontario returned for place_id 6a06dc5ecb2a02ef.
# 113: place_id 33659dbbd593f508
# Request successful. Place name Douro-Dummer, Ontario returned for place_id 33659dbbd593f508.
# 114: place_id 25596cb079a8e9c4
# Request successful. Place name Laval, Québec returned for place_id 25596cb079a8e9c4.
# 115: place_id 07acc59e29b2aedb
# Request successful. Place name Sarnia, Ontario returned for place_id 07acc59e29b2aedb.
# 116: place_id 71771c7c692226ab
# Request successful. Place name Port Hope, Ontario returned for place_id 71771c7c692226ab.
# 117: place_id 5e31b3ff3bbf4a50
# Request successful. Place name Colwood, British Columbia returned for place_id 5e31b3ff3bbf4a50.
# 118: place_id 0e1a6c315c033bf4
# Request successful. Place name Mission, British Columbia returned for place_id 0e1a6c315c033bf4.
# 119: place_id 4357e9f2c2d8a1a1
# Request successful. Place name Port Coquitlam, British Columbia returned for place_id 4357e9f2c2d8a1a1.
# 120: place_id 0199d644100e4631
# Request successful. Place name Port Alberni, British Columbia returned for place_id 0199d644100e4631.
# 121: place_id 446dd74cab94bc2c
# Request successful. Place name North Bay, Ontario returned for place_id 446dd74cab94bc2c.
# 122: place_id 2159675792ee9e69
# Request successful. Place name Oak Bay, British Columbia returned for place_id 2159675792ee9e69.
# 123: place_id 225aa50cbbde4a13
# Request successful. Place name Langford, British Columbia returned for place_id 225aa50cbbde4a13.
# 124: place_id 6272bcf0d50dfbb1
# Request successful. Place name Mississippi Mills, Ontario returned for place_id 6272bcf0d50dfbb1.
# 125: place_id 4516bcae4ad207f1
# Request successful. Place name Whistler, British Columbia returned for place_id 4516bcae4ad207f1.
# 126: place_id 727171d9d62ee901
# Request successful. Place name Lakeshore, Ontario returned for place_id 727171d9d62ee901.
# 127: place_id 0525ca0f47bca741
# Request successful. Place name Norfolk County, Ontario returned for place_id 0525ca0f47bca741.
# 128: place_id 0d3743b57bf55457
# Request successful. Place name Corner Brook, Newfoundland and Labrador returned for place_id 0d3743b57bf55457.
# 129: place_id 06fa737d271983ea
# Request successful. Place name Spruce Grove, Alberta returned for place_id 06fa737d271983ea.
# 130: place_id 049000e113eed437
# Request successful. Place name Vanderhoof, British Columbia returned for place_id 049000e113eed437.
# 131: place_id 576bdf29e34c5fce
# Request successful. Place name Grande Prairie, Alberta returned for place_id 576bdf29e34c5fce.
# 132: place_id 064e93acf98f7cf0
# Request successful. Place name Swift Current, Saskatchewan returned for place_id 064e93acf98f7cf0.
# 133: place_id 6108d4278199f54f
# Request successful. Place name Welland, Ontario returned for place_id 6108d4278199f54f.
# 134: place_id 04a5f5efa382b70d
# Request successful. Place name Rocky View County, Alberta returned for place_id 04a5f5efa382b70d.
# 135: place_id 402e618bff0d9dc1
# Request successful. Place name Niagara-on-the-Lake, Ontario returned for place_id 402e618bff0d9dc1.
# 136: place_id 89b2eb8b2b9847f7
# Request successful. Place name Ontario, Canada returned for place_id 89b2eb8b2b9847f7.
# 137: place_id 04cbec3ef8b7c868
# Request successful. Place name Leeds and the Thousand Islands, Ontario returned for place_id 04cbec3ef8b7c868.
# 138: place_id 07d9f618e9c85000
# Request successful. Place name Perley Rideau Veterans Health Centre returned for place_id 07d9f618e9c85000.
# 139: place_id 2a58f7a9b6979c9a
# Request successful. Place name Tsinstikeptum  9, British Columbia returned for place_id 2a58f7a9b6979c9a.
# 140: place_id 29ede02d5192bcad
# Request successful. Place name Stratford, Ontario returned for place_id 29ede02d5192bcad.
# 141: place_id 606774128b87a5b4
# Request successful. Place name Owen Sound, Ontario returned for place_id 606774128b87a5b4.
# 142: place_id 28605a9d7e03c0ca
# Request successful. Place name Cornwallis, Manitoba returned for place_id 28605a9d7e03c0ca.
# 143: place_id 1825c9e5b0366d7e
# Request successful. Place name Langley, British Columbia returned for place_id 1825c9e5b0366d7e.
# 144: place_id 3a8d0d494d8cd990
# Request successful. Place name Banff, Alberta returned for place_id 3a8d0d494d8cd990.
# 145: place_id 2b6388e36a136263
# Request successful. Place name Cochrane, Alberta returned for place_id 2b6388e36a136263.
# 146: place_id 3ca11fadbed4b58f
# Request successful. Place name Centre Wellington, Ontario returned for place_id 3ca11fadbed4b58f.
# 147: place_id 72dd0361fb23940d
# Request successful. Place name White Rock, British Columbia returned for place_id 72dd0361fb23940d.
# 148: place_id 28b85ac2e5adfefb
# Request successful. Place name Thames Centre, Ontario returned for place_id 28b85ac2e5adfefb.
# 149: place_id 0e194fe0d5b0eb7f
# Request successful. Place name Woolwich, Ontario returned for place_id 0e194fe0d5b0eb7f.
# 150: place_id 0a583341a1c11d40
# Request successful. Place name Fort Erie, Ontario returned for place_id 0a583341a1c11d40.
# 151: place_id 7a85f9e84c73837b
# Request successful. Place name Kenora, Ontario returned for place_id 7a85f9e84c73837b.
# 152: place_id 366d0c6807f583a3
# Request successful. Place name Sidney, British Columbia returned for place_id 366d0c6807f583a3.
# 153: place_id 07c2765f3c11e765
# Request successful. Place name Saugeen Shores, Ontario returned for place_id 07c2765f3c11e765.
# 154: place_id 30323e6f50298797
# Request successful. Place name Harrison Hot Springs, British Columbia returned for place_id 30323e6f50298797.
# 155: place_id 6c769785cb578e61
# Request successful. Place name Argyle, Manitoba returned for place_id 6c769785cb578e61.
# 156: place_id 133e76c8ced7070d
# Request successful. Place name Frontenac Islands, Ontario returned for place_id 133e76c8ced7070d.
# 157: place_id 00905fa63942b3ef
# Failed request. {"errors":[{"code":8,"message":"No data available for specified ID."}]}
# 158: place_id 4194d285edec464d
# Request successful. Place name Penticton, British Columbia returned for place_id 4194d285edec464d.
# 159: place_id 6a6fe0b30c8d83f5
# Request successful. Place name Strathmore, Alberta returned for place_id 6a6fe0b30c8d83f5.
# 160: place_id 7c11c5e9e8688203
# Request successful. Place name East Gwillimbury, Ontario returned for place_id 7c11c5e9e8688203.
# 161: place_id 0ac34e87a0e95f51
# Request successful. Place name Lake Cowichan, British Columbia returned for place_id 0ac34e87a0e95f51.
# 162: place_id 0ee312cd6e4c38cb
# Request successful. Place name Campbell River, British Columbia returned for place_id 0ee312cd6e4c38cb.
# 163: place_id 7ca1cd6dd86c1796
# Request successful. Place name Dysart and Others, Ontario returned for place_id 7ca1cd6dd86c1796.
# 164: place_id 55f9333f8a88cb6d
# Request successful. Place name King, Ontario returned for place_id 55f9333f8a88cb6d.
# 165: place_id 16efdbedf50f1971
# Request successful. Place name Stoney 142, 143, 144, Alberta returned for place_id 16efdbedf50f1971.
# 166: place_id 680015fddc2354ce
# Request successful. Place name Vernon, British Columbia returned for place_id 680015fddc2354ce.
# 167: place_id 1b43478b60b3d392
# Request successful. Place name Oakland, Manitoba returned for place_id 1b43478b60b3d392.
# 168: place_id 172883b089931b62
# Request successful. Place name Minto, Ontario returned for place_id 172883b089931b62.
# 169: place_id 3ec3ae6527ff6b28
# Request successful. Place name Whitchurch-Stouffville, Ontario returned for place_id 3ec3ae6527ff6b28.
# 170: place_id 721eff9856a56962
# Request successful. Place name Collingwood, Ontario returned for place_id 721eff9856a56962.
# 171: place_id 1089a6e11158515f
# Request successful. Place name Dorval, Québec returned for place_id 1089a6e11158515f.
# 172: place_id 24375e528db392ff
# Request successful. Place name Innisfil, Ontario returned for place_id 24375e528db392ff.
# 173: place_id 036806246ab02344
# Request successful. Place name Red Deer County, Alberta returned for place_id 036806246ab02344.
# 174: place_id 02bfa8238069803a
# Request successful. Place name Brockville, Ontario returned for place_id 02bfa8238069803a.
# 175: place_id 7d6107ba065931c9
# Request successful. Place name Guelph/Eramosa, Ontario returned for place_id 7d6107ba065931c9.
# 176: place_id 78fe2c7a7f085a0a
# Request successful. Place name Lincoln, Ontario returned for place_id 78fe2c7a7f085a0a.
# 177: place_id 25f162ba6cff7884
# Request successful. Place name Loyalist, Ontario returned for place_id 25f162ba6cff7884.
# 178: place_id 670b9b85ad376fa3
# Request successful. Place name Springwater, Ontario returned for place_id 670b9b85ad376fa3.
# 179: place_id d5caa4a626c68a25
# Request successful. Place name Division No. 10, Alberta returned for place_id d5caa4a626c68a25.
# 180: place_id 34537c41514b065e
# Request successful. Place name Westmorland, New Brunswick returned for place_id 34537c41514b065e.
# 181: place_id 4dbf0435afc240b7
# Request successful. Place name Gjoa Haven, Nunavut returned for place_id 4dbf0435afc240b7.
# 182: place_id 2ba9d25a3c65c05c
# Request successful. Place name West Kelowna, British Columbia returned for place_id 2ba9d25a3c65c05c.
# 183: place_id 16653c24ee3abbf7
# Request successful. Place name Prince Edward County, Ontario returned for place_id 16653c24ee3abbf7.
# 184: place_id 0d7dd6fd5c932108
# Request successful. Place name Leduc, Alberta returned for place_id 0d7dd6fd5c932108.
# 185: place_id 71eaa7927ef1a6e5
# Request successful. Place name Okotoks, Alberta returned for place_id 71eaa7927ef1a6e5.
# 186: place_id 4cbcbed1c52d1840
# Request successful. Place name Prince Albert, Saskatchewan returned for place_id 4cbcbed1c52d1840.
# 187: place_id 39fff0955b7e26a8
# Request successful. Place name Capital, British Columbia returned for place_id 39fff0955b7e26a8.
# 188: place_id 549510cfdf4c6efb
# Request successful. Place name Capital F, British Columbia returned for place_id 549510cfdf4c6efb.
# 189: place_id 4cc2a37edacbbb57
# Request successful. Place name Waskaganish, Québec returned for place_id 4cc2a37edacbbb57.
# 190: place_id 4503180063c06b49
# Request successful. Place name Pointe-Claire, Québec returned for place_id 4503180063c06b49.
# 191: place_id 07d9e47338885003
# Request successful. Place name Government House returned for place_id 07d9e47338885003.
# 192: place_id 43504b43f496e507
# Request successful. Place name Quinte West, Ontario returned for place_id 43504b43f496e507.
# 193: place_id 0f3720411562626d
# Request successful. Place name South Frontenac, Ontario returned for place_id 0f3720411562626d.
# 194: place_id 5178fe257321f63d
# Request successful. Place name Wasaga Beach, Ontario returned for place_id 5178fe257321f63d.
# 195: place_id 312f824e8ae3e6c4
# Request successful. Place name Brant, Ontario returned for place_id 312f824e8ae3e6c4.
# 196: place_id 96afdcaea18d3386
# Request successful. Place name Alberta, Canada returned for place_id 96afdcaea18d3386.
# 197: place_id 4a0cd47b60820d6f
# Request successful. Place name Kings, Subd. B, Nova Scotia returned for place_id 4a0cd47b60820d6f.
# 198: place_id 389c8097b8f93de7
# Request successful. Place name Kamloops 1, British Columbia returned for place_id 389c8097b8f93de7.
# 199: place_id 3734d95467e9e088
# Request successful. Place name Nelson, British Columbia returned for place_id 3734d95467e9e088.
# 200: place_id 4ee01b9baecf09e7
# Request successful. Place name Essa, Ontario returned for place_id 4ee01b9baecf09e7.
# 100 requests limit reached. Sleeping for 15 minutes...
# Resuming requests...
# 201: place_id 51ab7a72c2cd1a54
# Request successful. Place name Fraser Valley, British Columbia returned for place_id 51ab7a72c2cd1a54.
# 202: place_id 75ab06e13e8d6de0
# Request successful. Place name Warman, Saskatchewan returned for place_id 75ab06e13e8d6de0.
# 203: place_id 33cdf8b73898aa55
# Request successful. Place name Squamish, British Columbia returned for place_id 33cdf8b73898aa55.
# 204: place_id 2e3cdf75ea608148
# Request successful. Place name Barrhead, Alberta returned for place_id 2e3cdf75ea608148.
# 205: place_id 77482966ae52a4ae
# Request successful. Place name Lunenburg, Nova Scotia returned for place_id 77482966ae52a4ae.
# 206: place_id 7c80a0b9e0482c00
# Request successful. Place name Powell River, British Columbia returned for place_id 7c80a0b9e0482c00.
# 207: place_id 2b1f7af594bee04e
# Request successful. Place name Ramara, Ontario returned for place_id 2b1f7af594bee04e.
# 208: place_id 6681d5e2139a448e
# Request successful. Place name North Grenville, Ontario returned for place_id 6681d5e2139a448e.
# 209: place_id 436d8520fb94e043
# Request successful. Place name Cornwall, Ontario returned for place_id 436d8520fb94e043.
# 210: place_id 6cc5e1177d4f7204
# Request successful. Place name Summerland, British Columbia returned for place_id 6cc5e1177d4f7204.
# 211: place_id 5d158f582b4ee07e
# Request successful. Place name Parkland County, Alberta returned for place_id 5d158f582b4ee07e.
# 212: place_id 20b0cabb7578c4c9
# Request successful. Place name Mont-Royal, Québec returned for place_id 20b0cabb7578c4c9.
# 213: place_id 2025d702834f218b
# Request successful. Place name Burrard Inlet 3, British Columbia returned for place_id 2025d702834f218b.
# 214: place_id 7e5e9e60425176fe
# Request successful. Place name Gravenhurst, Ontario returned for place_id 7e5e9e60425176fe.
# 215: place_id 6e62d289c1553afd
# Request successful. Place name North Cowichan, British Columbia returned for place_id 6e62d289c1553afd.
# 216: place_id 788ea89e0574da50
# Request successful. Place name Smith-Ennismore-Lakefield, Ontario returned for place_id 788ea89e0574da50.
# 217: place_id 1bc6f9af7540ab03
# Request successful. Place name Yorkton, Saskatchewan returned for place_id 1bc6f9af7540ab03.
# 218: place_id 51fa1a6f3ba74ba9
# Request successful. Place name Wilmot, Ontario returned for place_id 51fa1a6f3ba74ba9.
# 219: place_id 208572f447bdc7e5
# Request successful. Place name Lajord No. 128, Saskatchewan returned for place_id 208572f447bdc7e5.
# 220: place_id 07d9c93f42486004
# Request successful. Place name Alberta Legislature returned for place_id 07d9c93f42486004.
# 221: place_id 6c7f370d7c03f2ca
# Request successful. Place name Sylvan Lake, Alberta returned for place_id 6c7f370d7c03f2ca.
# 222: place_id 2de55725306af67b
# Request successful. Place name Foothills No. 31, Alberta returned for place_id 2de55725306af67b.
# 223: place_id 18d4b7e266c62a04
# Request successful. Place name Sturgeon County, Alberta returned for place_id 18d4b7e266c62a04.
# 224: place_id 1ce9096a06bb481d
# Request successful. Place name Beaumont, Alberta returned for place_id 1ce9096a06bb481d.
# 225: place_id 63f7d7a30d0d1242
# Request successful. Place name The Blue Mountains, Ontario returned for place_id 63f7d7a30d0d1242.
# 226: place_id 1fc97c436e62f8e6
# Request successful. Place name Leduc County, Alberta returned for place_id 1fc97c436e62f8e6.
# 227: place_id 7d328f290343463a
# Request successful. Place name Strathroy-Caradoc, Ontario returned for place_id 7d328f290343463a.
# 228: place_id 0d1a6a86b5c1190c
# Request successful. Place name Huntsville, Ontario returned for place_id 0d1a6a86b5c1190c.
# 229: place_id 23b06d1c5848c76d
# Request successful. Place name Louise, Manitoba returned for place_id 23b06d1c5848c76d.
# 230: place_id 268b61b7e3cf7a78
# Request successful. Place name Morinville, Alberta returned for place_id 268b61b7e3cf7a78.
# 231: place_id 379c4cf2fb432022
# Request successful. Place name Lacombe, Alberta returned for place_id 379c4cf2fb432022.
# 232: place_id 10aa607790ac4421
# Request successful. Place name South Glengarry, Ontario returned for place_id 10aa607790ac4421.
# 233: place_id 07d9eda840088001
# Request successful. Place name Woodbridge, Ontario returned for place_id 07d9eda840088001.
# 234: place_id 2da96b453ca10cc8
# Request successful. Place name Merrickville-Wolford, Ontario returned for place_id 2da96b453ca10cc8.
# 235: place_id 01aed5942caaba8d
# Request successful. Place name Pelham, Ontario returned for place_id 01aed5942caaba8d.
# 236: place_id 18ffde267c70ca81
# Request successful. Place name Otonabee-South Monaghan, Ontario returned for place_id 18ffde267c70ca81.
# 237: place_id 0d448e723c337c0e
# Request successful. Place name Paradise, Newfoundland and Labrador returned for place_id 0d448e723c337c0e.
# 238: place_id 1d1419bc23159bae
# Request successful. Place name Behchokò, Northwest Territories returned for place_id 1d1419bc23159bae.
# 239: place_id 2f89e55b289b1190
# Request successful. Place name Pond Inlet, Nunavut returned for place_id 2f89e55b289b1190.
# 240: place_id 470e7074ff63c9ef
# Request successful. Place name Thorold, Ontario returned for place_id 470e7074ff63c9ef.
# 241: place_id 7fb65eafafe234bf
# Request successful. Place name Oro-Medonte, Ontario returned for place_id 7fb65eafafe234bf.
# 242: place_id 691faf928074005b
# Request successful. Place name Midland, Ontario returned for place_id 691faf928074005b.
# 243: place_id 4398db45a384c7e8
# Request successful. Place name Torbay, Newfoundland and Labrador returned for place_id 4398db45a384c7e8.
# 244: place_id 3e71718681740cba
# Request successful. Place name British Columbia, Canada returned for place_id 3e71718681740cba.
# 245: place_id 1cfa1623a8eb155e
# Request successful. Place name Brossard, Québec returned for place_id 1cfa1623a8eb155e.
# 246: place_id 1c3336566423706d
# Request successful. Place name Lloydminster (Part), Saskatchewan returned for place_id 1c3336566423706d.
# 247: place_id 22c835a587baa5ea
# Request successful. Place name Salmon Arm, British Columbia returned for place_id 22c835a587baa5ea.
# 248: place_id 43d1c0bfef959e7d
# Request successful. Place name Bradford West Gwillimbury, Ontario returned for place_id 43d1c0bfef959e7d.
# 249: place_id 4364e9390c1e0f76
# Request successful. Place name Tsuu T'ina Nation 145 (Sarcee 145), Alberta returned for place_id 4364e9390c1e0f76.
# 250: place_id 07d9f7e0f0880001
# Request successful. Place name Wawel Villa returned for place_id 07d9f7e0f0880001.
# 251: place_id 6c0d9557b3ab0146
# Request successful. Place name Tecumseh, Ontario returned for place_id 6c0d9557b3ab0146.
# 252: place_id 0fc54aef640684a5
# Request successful. Place name M'Chigeeng 22 (West Bay 22), Ontario returned for place_id 0fc54aef640684a5.
# 253: place_id 49ea1b60dc53a196
# Request successful. Place name Laurentian Valley, Ontario returned for place_id 49ea1b60dc53a196.
# 254: place_id 788a87e8ab58176b
# Request successful. Place name Rothesay, New Brunswick returned for place_id 788a87e8ab58176b.
# 255: place_id 192169a285bcfbdc
# Request successful. Place name Stephenville, Newfoundland and Labrador returned for place_id 192169a285bcfbdc.
# 256: place_id 5202d5246e93db16
# Request successful. Place name Port Colborne, Ontario returned for place_id 5202d5246e93db16.
# 257: place_id 5a0b2991f0b59db3
# Request successful. Place name Williams Lake, British Columbia returned for place_id 5a0b2991f0b59db3.
# 258: place_id 6c38621b1c0d267c
# Request successful. Place name Bracebridge, Ontario returned for place_id 6c38621b1c0d267c.
# 259: place_id 29271dc88dffe3cf
# Request successful. Place name Bella Bella 1, British Columbia returned for place_id 29271dc88dffe3cf.
# 260: place_id 390f657dacb510f6
# Request successful. Place name Miramichi, New Brunswick returned for place_id 390f657dacb510f6.
# 261: place_id 3ab7245254ffbacb
# Request successful. Place name Clearview, Ontario returned for place_id 3ab7245254ffbacb.
# 262: place_id 066e66c6e192cd93
# Request successful. Place name Kahnawake, Québec returned for place_id 066e66c6e192cd93.
# 263: place_id 41b067f0c08a4dff
# Request successful. Place name Colchester, Subd. C, Nova Scotia returned for place_id 41b067f0c08a4dff.
# 264: place_id 005a7c16c8940d53
# Request successful. Place name Kings, Subd. A, Nova Scotia returned for place_id 005a7c16c8940d53.
# 265: place_id 27d5b5a8109d1f54
# Request successful. Place name Dieppe, New Brunswick returned for place_id 27d5b5a8109d1f54.
# 266: place_id 544208594112a39c
# Request successful. Place name Prince Rupert, British Columbia returned for place_id 544208594112a39c.
# 267: place_id 3cf33884f56577ad
# Request successful. Place name Nanaimo B, British Columbia returned for place_id 3cf33884f56577ad.
# 268: place_id 17707b34c87c5471
# Request successful. Place name Penetanguishene, Ontario returned for place_id 17707b34c87c5471.
# 269: place_id 07d9d223ab084000
# Request successful. Place name Legislative Assembly of Ontario returned for place_id 07d9d223ab084000.
# 270: place_id 3e586c3008646ed3
# Request successful. Place name Corman Park No. 344, Saskatchewan returned for place_id 3e586c3008646ed3.
# 271: place_id 3c26e32ff14f796f
# Request successful. Place name Ingersoll, Ontario returned for place_id 3c26e32ff14f796f.
# 272: place_id 5daca4d25e4df561
# Request successful. Place name Fort St. John, British Columbia returned for place_id 5daca4d25e4df561.
# 273: place_id 152135cb46a87071
# Request successful. Place name Willner No. 253, Saskatchewan returned for place_id 152135cb46a87071.
# 274: place_id 3da3aec3aee0dd7f
# Request successful. Place name Drumheller, Alberta returned for place_id 3da3aec3aee0dd7f.
# 275: place_id 0b726f4f220e6db5
# Request successful. Place name High River, Alberta returned for place_id 0b726f4f220e6db5.
# 276: place_id 629b4f002342b1c4
# Request successful. Place name East Hants, Nova Scotia returned for place_id 629b4f002342b1c4.
# 277: place_id 55396b35a273afaa
# Request successful. Place name Fort Frances, Ontario returned for place_id 55396b35a273afaa.
# 278: place_id 6eafdcba63b6591f
# Request successful. Place name Comox, British Columbia returned for place_id 6eafdcba63b6591f.
# 279: place_id 5c2cd46c79aa7b08
# Request successful. Place name Pictou, Nova Scotia returned for place_id 5c2cd46c79aa7b08.
# 280: place_id 03838537545e2fe7
# Request successful. Place name Camrose, Alberta returned for place_id 03838537545e2fe7.
# 281: place_id 51079e95205a7bf4
# Request successful. Place name Tillsonburg, Ontario returned for place_id 51079e95205a7bf4.
# 282: place_id 7577d7e2d0852b50
# Request successful. Place name Cowichan Valley A, British Columbia returned for place_id 7577d7e2d0852b50.
# 283: place_id 5c8e1e44a704aa75
# Request successful. Place name LaSalle, Ontario returned for place_id 5c8e1e44a704aa75.
# 284: place_id 7f361884163c6dfc
# Request successful. Place name Terrell No. 101, Saskatchewan returned for place_id 7f361884163c6dfc.
# 285: place_id 4efd2890ffa7ef7a
# Request successful. Place name Arnprior, Ontario returned for place_id 4efd2890ffa7ef7a.
# 286: place_id 5b862064b98d0be9
# Request successful. Place name Lake of Bays, Ontario returned for place_id 5b862064b98d0be9.
# 287: place_id 0a48b792b2a27a22
# Request successful. Place name Altona, Manitoba returned for place_id 0a48b792b2a27a22.
# 288: place_id 2f45383a046c013a
# Request successful. Place name East Saanich 2, British Columbia returned for place_id 2f45383a046c013a.
# 289: place_id 5a94e42203f4c886
# Request successful. Place name Haldimand County, Ontario returned for place_id 5a94e42203f4c886.
# 290: place_id 0cfd1aa80141b7aa
# Request successful. Place name Clarenville, Newfoundland and Labrador returned for place_id 0cfd1aa80141b7aa.
# 291: place_id 6a96306e8d4b1bea
# Request successful. Place name Dollard-Des Ormeaux, Québec returned for place_id 6a96306e8d4b1bea.
# 292: place_id 67a847719eb471c3
# Request successful. Place name West Lincoln, Ontario returned for place_id 67a847719eb471c3.
# 293: place_id 53cd5bbdd4e184e0
# Request successful. Place name Longueuil, Québec returned for place_id 53cd5bbdd4e184e0.
# 294: place_id 7c080be8b8fc0e44
# Request successful. Place name Greater Napanee, Ontario returned for place_id 7c080be8b8fc0e44.
# 295: place_id 1c81d5515a4aad20
# Request successful. Place name Beaconsfield, Québec returned for place_id 1c81d5515a4aad20.
# 296: place_id 773bbcc04baaa9cd
# Request successful. Place name Brant, Ontario returned for place_id 773bbcc04baaa9cd.
# 297: place_id 66b15015315376ba
# Request successful. Place name Cypress County, Alberta returned for place_id 66b15015315376ba.
# 298: place_id 4e0f8e1543e64005
# Request successful. Place name Scugog, Ontario returned for place_id 4e0f8e1543e64005.
# 299: place_id 7bb60fdeeb129a0d
# Request successful. Place name Inuvik, Northwest Territories returned for place_id 7bb60fdeeb129a0d.
# 300: place_id 11ece51fc0f67d5f
# Request successful. Place name Bathurst, New Brunswick returned for place_id 11ece51fc0f67d5f.
# 100 requests limit reached. Sleeping for 15 minutes...
# Resuming requests...
# 301: place_id 081ffd6543691d3e
# Request successful. Place name Thompson-Nicola B (Thompson Headwaters), British Columbia returned for place_id 081ffd6543691d3e.
# 302: place_id 755b1ca43cafa130
# Request successful. Place name Grey Highlands, Ontario returned for place_id 755b1ca43cafa130.
# 303: place_id 4502c2faccc8327b
# Request successful. Place name Kirkland, Québec returned for place_id 4502c2faccc8327b.
# 304: place_id 08a6a7a84eddcc9c
# Request successful. Place name Perth, Ontario returned for place_id 08a6a7a84eddcc9c.
# 305: place_id 196de9e1f6dcc3da
# Request successful. Place name Mono, Ontario returned for place_id 196de9e1f6dcc3da.
# 306: place_id 707d7022fd2ee2f2
# Request successful. Place name Lac Ste. Anne County, Alberta returned for place_id 707d7022fd2ee2f2.
# 307: place_id 59f84b7bad05e167
# Request successful. Place name Grimsby, Ontario returned for place_id 59f84b7bad05e167.
# 308: place_id 2d349ca082bcc8f0
# Request successful. Place name Millbrook 27, Nova Scotia returned for place_id 2d349ca082bcc8f0.
# 309: place_id 3fc1a8716d00ac49
# Request successful. Place name Cowichan Valley B, British Columbia returned for place_id 3fc1a8716d00ac49.
# 310: place_id 3b4464df1a9302b1
# Request successful. Place name Trois-Rivières, Québec returned for place_id 3b4464df1a9302b1.
# 311: place_id 237db9ba7fec71bb
# Request successful. Place name Nipissing 10, Ontario returned for place_id 237db9ba7fec71bb.
# 312: place_id 2146ac380d2cc6cd
# Request successful. Place name Cache Creek, British Columbia returned for place_id 2146ac380d2cc6cd.
# 313: place_id 18cce854e5162027
# Request successful. Place name Severn, Ontario returned for place_id 18cce854e5162027.
# 314: place_id 07d9df8944488000
# Request successful. Place name Rekai Centre returned for place_id 07d9df8944488000.
# 315: place_id 4b426e22bf691a83
# Request successful. Place name Courtenay, British Columbia returned for place_id 4b426e22bf691a83.
# 316: place_id 13cb6c64bdeba9a1
# Request successful. Place name Grande Prairie County No. 1, Alberta returned for place_id 13cb6c64bdeba9a1.
# 317: place_id 73ae9d97d81a3737
# Request successful. Place name Mountain View County, Alberta returned for place_id 73ae9d97d81a3737.
# 318: place_id 033ae1255d0ccd5a
# Request successful. Place name Summerside, Prince Edward Island returned for place_id 033ae1255d0ccd5a.
# 319: place_id 0fc296978b155000
# Request successful. Place name Chinese Cultural Centre of Greater Toronto 大多倫多中華文化中心 returned for place_id 0fc296978b155000.
# 320: place_id 07d9f6ef1b883002
# Request successful. Place name Cedarglen Gate returned for place_id 07d9f6ef1b883002.
# 321: place_id 59b1b9cae0994377
# Request successful. Place name Sooke, British Columbia returned for place_id 59b1b9cae0994377.
# 322: place_id 275c242eb2105e0a
# Request successful. Place name Westmount, Québec returned for place_id 275c242eb2105e0a.
# 323: place_id 5ca6f0f1ef4af75d
# Request successful. Place name Rockwood, Manitoba returned for place_id 5ca6f0f1ef4af75d.
# 324: place_id 01a9fdd98a942d7e
# Request successful. Place name Montcalm, Manitoba returned for place_id 01a9fdd98a942d7e.
# 325: place_id 8f9664a8ccd89e5c
# Request successful. Place name Toronto, Ontario returned for place_id 8f9664a8ccd89e5c.
# 326: place_id 7de4936a6c21cfdc
# Request successful. Place name Saint David, New Brunswick returned for place_id 7de4936a6c21cfdc.
# 327: place_id 69e286fe7dee6757
# Request successful. Place name Tyendinaga Mohawk Territory, Ontario returned for place_id 69e286fe7dee6757.
# 328: place_id 4c3ca21af889133b
# Request successful. Place name Kings, Subd. C, Nova Scotia returned for place_id 4c3ca21af889133b.
# 329: place_id 36d6462291eb87ae
# Request successful. Place name South Bruce Peninsula, Ontario returned for place_id 36d6462291eb87ae.
# 330: place_id 72ec8d7f5f08467a
# Request successful. Place name Kincardine, Ontario returned for place_id 72ec8d7f5f08467a.
# 331: place_id 6e7cfa629cf22ad0
# Request successful. Place name Ste. Rose, Manitoba returned for place_id 6e7cfa629cf22ad0.
# 332: place_id 58475b55221b6429
# Request successful. Place name Champlain, Ontario returned for place_id 58475b55221b6429.
# 333: place_id 4562497b08829354
# Request successful. Place name Parksville, British Columbia returned for place_id 4562497b08829354.
# 334: place_id 182df90fac81f143
# Request successful. Place name Annapolis, Subd. A, Nova Scotia returned for place_id 182df90fac81f143.
# 335: place_id 1240d50b4ec627d5
# Request successful. Place name Stratford, Prince Edward Island returned for place_id 1240d50b4ec627d5.
# 336: place_id 130c74fb6394613a
# Request successful. Place name Steinbach, Manitoba returned for place_id 130c74fb6394613a.
# 337: place_id 71dd71a82c96ad81
# Request successful. Place name Chelsea, Québec returned for place_id 71dd71a82c96ad81.
# 338: place_id 00dbbae2332899aa
# Request successful. Place name Mount Pleasant, Vancouver returned for place_id 00dbbae2332899aa.
# 339: place_id 6bab9125eefc4f1b
# Request successful. Place name Rocky Harbour, Newfoundland and Labrador returned for place_id 6bab9125eefc4f1b.
# 340: place_id 543b869fcb979cdf
# Request successful. Place name Slave Lake, Alberta returned for place_id 543b869fcb979cdf.
# 341: place_id 18dcbf79233245a1
# Request successful. Place name Goderich, Ontario returned for place_id 18dcbf79233245a1.
# 342: place_id 1b88006de3e41da9
# Request successful. Place name Alfred and Plantagenet, Ontario returned for place_id 1b88006de3e41da9.
# 343: place_id 2a24460ae2d93f7b
# Request successful. Place name Chestermere, Alberta returned for place_id 2a24460ae2d93f7b.
# 344: place_id 5e6bce5f97a34c4c
# Request successful. Place name Whycocomagh 2, Nova Scotia returned for place_id 5e6bce5f97a34c4c.
# 345: place_id 72a7815518048324
# Request successful. Place name Division No.  5, Subd. F, Newfoundland and Labrador returned for place_id 72a7815518048324.
# 346: place_id 1299f301a0e920cc
# Request successful. Place name Kings, Subd. D, Nova Scotia returned for place_id 1299f301a0e920cc.
# 347: place_id 0064529d5fb32582
# Request successful. Place name Georgian Bluffs, Ontario returned for place_id 0064529d5fb32582.
# 348: place_id 419642215e9dbcb6
# Request successful. Place name Portugal Cove-St. Philip's, Newfoundland and Labrador returned for place_id 419642215e9dbcb6.
# 349: place_id 60b4f65783e85c93
# Request successful. Place name Lac la Biche County, Alberta returned for place_id 60b4f65783e85c93.
# 350: place_id 2d9570c084cf8a31
# Request successful. Place name Capital G, British Columbia returned for place_id 2d9570c084cf8a31.
# 351: place_id 4c397f34466356d6
# Request successful. Place name Kingsville, Ontario returned for place_id 4c397f34466356d6.
# 352: place_id 340b5963ff54c668
# Request successful. Place name Olds, Alberta returned for place_id 340b5963ff54c668.
# 353: place_id 08b23e7a72aa3705
# Request successful. Place name Merritt, British Columbia returned for place_id 08b23e7a72aa3705.
# 354: place_id 651bfbe25cdb8ba9
# Request successful. Place name Comox Valley A, British Columbia returned for place_id 651bfbe25cdb8ba9.
# 355: place_id 6a58528274bb9e12
# Request successful. Place name Wainwright No. 61, Alberta returned for place_id 6a58528274bb9e12.
# 356: place_id 7638338dc8a77356
# Request successful. Place name Uxbridge, Ontario returned for place_id 7638338dc8a77356.
# 357: place_id 0bae3c62f3193122
# Request successful. Place name Côte-Saint-Luc, Québec returned for place_id 0bae3c62f3193122.
# 358: place_id 6e1630ab87b97ca3
# Request successful. Place name Ponoka, Alberta returned for place_id 6e1630ab87b97ca3.
# 359: place_id 323910ee98811173
# Request successful. Place name Meaford, Ontario returned for place_id 323910ee98811173.
# 360: place_id 701b7d92002f366d
# Request successful. Place name Brighton, Ontario returned for place_id 701b7d92002f366d.
# 361: place_id 36831992ce86d949
# Request successful. Place name Inukjuak, Québec returned for place_id 36831992ce86d949.
# 362: place_id 7b511db3bfdbdc44
# Request successful. Place name Garden River 14, Ontario returned for place_id 7b511db3bfdbdc44.
# 363: place_id 3f767a84de8478c5
# Request successful. Place name East Kootenay F, British Columbia returned for place_id 3f767a84de8478c5.
# 364: place_id 5f9fa4597601cc29
# Request successful. Place name Lethbridge County, Alberta returned for place_id 5f9fa4597601cc29.
# 365: place_id 29fcd8401ae416ad
# Request successful. Place name Elizabethtown-Kitley, Ontario returned for place_id 29fcd8401ae416ad.
# 366: place_id 4eab1c58d3cc678e
# Request successful. Place name West Elgin, Ontario returned for place_id 4eab1c58d3cc678e.
# 367: place_id aaf47682e345b807
# Request successful. Place name Saskatchewan, Canada returned for place_id aaf47682e345b807.
# 368: place_id 5cd2c4ae081ae933
# Request successful. Place name Essex, Ontario returned for place_id 5cd2c4ae081ae933.
# 369: place_id 227068e8d54227bc
# Request successful. Place name Dawson, Yukon returned for place_id 227068e8d54227bc.
# 370: place_id 2d4df558687080a8
# Request successful. Place name South Stormont, Ontario returned for place_id 2d4df558687080a8.
# 371: place_id 489949c836ba84c5
# Request successful. Place name Sioux Lookout, Ontario returned for place_id 489949c836ba84c5.
# 372: place_id 56e6267bc475e580
# Request successful. Place name Middlesex Centre, Ontario returned for place_id 56e6267bc475e580.
# 373: place_id 099a31ae6e5b71ea
# Request successful. Place name Edson, Alberta returned for place_id 099a31ae6e5b71ea.
# 374: place_id 573b80d14e7a8f69
# Request successful. Place name Strathcona D (Oyster Bay - Buttle Lake), British Columbia returned for place_id 573b80d14e7a8f69.
# 375: place_id 3b1c87646ffcd3f7
# Request successful. Place name Smithers, British Columbia returned for place_id 3b1c87646ffcd3f7.
# 376: place_id 1a3992d3e8b14704
# Request successful. Place name Elbow, Saskatchewan returned for place_id 1a3992d3e8b14704.
# 377: place_id 67191bfd96bb6d69
# Request successful. Place name Port Hawkesbury, Nova Scotia returned for place_id 67191bfd96bb6d69.
# 378: place_id 649f54014dd752c9
# Request successful. Place name Tsawwassen, British Columbia returned for place_id 649f54014dd752c9.
# 379: place_id 3db04ec44e0fb826
# Request successful. Place name Hamilton, Ontario returned for place_id 3db04ec44e0fb826.
# 380: place_id 7675931fc12459d1
# ...
# 677: place_id 59e021aec3a8ec52
# Request successful. Place name Six Nations (Part) 40, Ontario returned for place_id 59e021aec3a8ec52.
# 678: place_id 07d9cc5a02884002
# Request successful. Place name Metro Toronto Convention Centre - South Building returned for place_id 07d9cc5a02884002.
# 679: place_id 07d9dbb921c86001
# Request successful. Place name Michelangelos Banquet Center returned for place_id 07d9dbb921c86001.
# 680: place_id 89cf852bdd943da7
# Request successful. Place name Nunavut, Canada returned for place_id 89cf852bdd943da7.
# 681: place_id 5d95e02c54d75864
# Request successful. Place name Drummondville, Québec returned for place_id 5d95e02c54d75864.
# 682: place_id 07d9eee0e4480002
# Request successful. Place name Yee Hong Garden Terrace returned for place_id 07d9eee0e4480002.
# 683: place_id 00c68687676b186d
# Request successful. Place name Downtown, Vancouver returned for place_id 00c68687676b186d.
# 684: place_id 22702c3007c61bf2
# Request successful. Place name Logy Bay-Middle Cove-Outer Cove, Newfoundland and Labrador returned for place_id 22702c3007c61bf2.
# 685: place_id 07d9f4579b488001
# Request successful. Place name First Nations Longhouse returned for place_id 07d9f4579b488001.
# 686: place_id 563c5f33013eec7a
# Request successful. Place name Fernie, British Columbia returned for place_id 563c5f33013eec7a.
# 687: place_id 07d9d2c0a7483005
# Request successful. Place name Port Credit returned for place_id 07d9d2c0a7483005.
# 688: place_id 7de6351ad52f4c6f
# Request successful. Place name Richibucto 15, New Brunswick returned for place_id 7de6351ad52f4c6f.
# 689: place_id 6a1743e447966b0c
# Request successful. Place name Gibsons, British Columbia returned for place_id 6a1743e447966b0c.
# 690: place_id 2cc34b9376b2a9a8
# Request successful. Place name Division No. 18, Unorganized, Saskatchewan returned for place_id 2cc34b9376b2a9a8.
# 691: place_id 60b93f98cbb88fee
# Request successful. Place name Grenville, Québec returned for place_id 60b93f98cbb88fee.
# 692: place_id 1d60816cfb26c703
# Request successful. Place name Waswanipi, Québec returned for place_id 1d60816cfb26c703.
# 693: place_id 07d9ec8005c81000
# Request successful. Place name National Arts Centre - Centre National des Arts returned for place_id 07d9ec8005c81000.
# 694: place_id 247e504739df1e34
# Request successful. Place name Lumby, British Columbia returned for place_id 247e504739df1e34.
# 695: place_id 6f3f94a19c224f9b
# Request successful. Place name Mount Carmel-Mitchells Brook-St. Catherine's, Newfoundland and Labrador returned for place_id 6f3f94a19c224f9b.
# 696: place_id 09471a847de28359
# Request successful. Place name Gitanmaax 1, British Columbia returned for place_id 09471a847de28359.
# 697: place_id 394bb115600c5dff
# Request successful. Place name Cowichan Valley H, British Columbia returned for place_id 394bb115600c5dff.
# 698: place_id 40f4939c64f1bf53
# Request successful. Place name Skwah 4, British Columbia returned for place_id 40f4939c64f1bf53.
# 699: place_id 6efd96333e6dacef
# Request successful. Place name Houston, British Columbia returned for place_id 6efd96333e6dacef.
# 700: place_id 456c5244b2da1521
# Request successful. Place name Montague, Prince Edward Island returned for place_id 456c5244b2da1521.
# 100 requests limit reached. Sleeping for 15 minutes...
# Resuming requests...
# 701: place_id 07d9ec9c77885002
# Request successful. Place name London Drugs returned for place_id 07d9ec9c77885002.
# 702: place_id 7b292a43ff8c213b
# Request successful. Place name Point Edward, Ontario returned for place_id 7b292a43ff8c213b.
# 703: place_id 0769ae1d266551d1
# Request successful. Place name Couchiching 16A, Ontario returned for place_id 0769ae1d266551d1.
# 704: place_id 07d9f325e8885000
# Request successful. Place name Ottawa City Hall returned for place_id 07d9f325e8885000.
# 705: place_id 07d9db0076885000
# Request successful. Place name Canadian Museum of History returned for place_id 07d9db0076885000.
# 706: place_id 07d9e3a31b082002
# Request successful. Place name East York Community Centre returned for place_id 07d9e3a31b082002.
# 707: place_id 6e30980c4283b230
# Request successful. Place name Nobleford, Alberta returned for place_id 6e30980c4283b230.
# 708: place_id 58c344e92b360486
# Request successful. Place name Innisfail, Alberta returned for place_id 58c344e92b360486.
# 709: place_id d3f39888bb7ef409
# Request successful. Place name Manitoba, Canada returned for place_id d3f39888bb7ef409.
# 710: place_id 1cc4ccf111261d90
# Request successful. Place name Capital H (Part 1), British Columbia returned for place_id 1cc4ccf111261d90.
# 711: place_id 66a54c760d80419c
# Request successful. Place name Hawkesbury, Ontario returned for place_id 66a54c760d80419c.
# 712: place_id 661ff6723d6ec4b0
# Request successful. Place name Mount Currie, British Columbia returned for place_id 661ff6723d6ec4b0.
# 713: place_id 151cf6e237ecffd8
# Request successful. Place name Dawson Creek, British Columbia returned for place_id 151cf6e237ecffd8.
# 714: place_id 2f604b811224bbe8
# Request successful. Place name Camrose County, Alberta returned for place_id 2f604b811224bbe8.
# 715: place_id 2dd85a99d4937e45
# Request successful. Place name Dorion, Ontario returned for place_id 2dd85a99d4937e45.
# 716: place_id 2c51f689651b7232
# Request successful. Place name Athabasca County, Alberta returned for place_id 2c51f689651b7232.
# 717: place_id 6466e8f8a8075934
# Request successful. Place name Daysland, Alberta returned for place_id 6466e8f8a8075934.
# 718: place_id 7d08f03bc946ebd2
# Request successful. Place name Bulkley-Nechako D, British Columbia returned for place_id 7d08f03bc946ebd2.
# 719: place_id fff592dc17365476
# Request successful. Place name Division No. 17, Manitoba returned for place_id fff592dc17365476.
# 720: place_id 06cfc0dbbdbe2fc9
# Request successful. Place name Elton, Manitoba returned for place_id 06cfc0dbbdbe2fc9.
# 721: place_id 07d9f73e4d881003
# Request successful. Place name North Toronto Memorial Community Centre returned for place_id 07d9f73e4d881003.
# 722: place_id 3505c2f21385fc5a
# Request successful. Place name Thompson, Manitoba returned for place_id 3505c2f21385fc5a.
# 723: place_id 6738918561f31a6b
# Request successful. Place name Cowichan Valley C, British Columbia returned for place_id 6738918561f31a6b.
# 724: place_id bb87236e9e538045
# Request successful. Place name Lambton, Ontario returned for place_id bb87236e9e538045.
# 725: place_id 451359112b681d02
# Request successful. Place name Mirabel, Québec returned for place_id 451359112b681d02.
# 726: place_id 4334903d32077699
# Request successful. Place name Hudson, Québec returned for place_id 4334903d32077699.
# 727: place_id 6001aa93d22744c4
# Request successful. Place name North Middlesex, Ontario returned for place_id 6001aa93d22744c4.
# 728: place_id 39249fe93fab04fe
# Request successful. Place name Kingsclear, New Brunswick returned for place_id 39249fe93fab04fe.
# 729: place_id 58944065255b5fa0
# Request successful. Place name Candiac, Québec returned for place_id 58944065255b5fa0.
# 730: place_id 74f90ebbb57b4dc1
# Request successful. Place name Walpole Island 46, Ontario returned for place_id 74f90ebbb57b4dc1.
# 731: place_id 1908154d4b5d1f43
# Request successful. Place name Wolfville, Nova Scotia returned for place_id 1908154d4b5d1f43.
# 732: place_id 49722fab6449ab71
# Request successful. Place name Nipissing, Unorganized, North Part, Ontario returned for place_id 49722fab6449ab71.
# 733: place_id 7598e25037075767
# Request successful. Place name Channel-Port aux Basques, Newfoundland and Labrador returned for place_id 7598e25037075767.
# 734: place_id 07d9d23bcfc83002
# Request successful. Place name Regency Palace Restaurant returned for place_id 07d9d23bcfc83002.
# 735: place_id 52452903e68e0c0c
# Request successful. Place name Whitecourt, Alberta returned for place_id 52452903e68e0c0c.
# 736: place_id 7123146be5706d97
# Request successful. Place name Eatonia, Saskatchewan returned for place_id 7123146be5706d97.
# 737: place_id 335325831c5169fa
# Request successful. Place name Durham, New Brunswick returned for place_id 335325831c5169fa.
# 738: place_id 07d9e6b6ec484000
# Request successful. Place name Glen Lea Golf Course returned for place_id 07d9e6b6ec484000.
# 739: place_id 5163b396888c3805
# Request successful. Place name Sunshine Coast B, British Columbia returned for place_id 5163b396888c3805.
# 740: place_id 15b0997f0520713b
# Request successful. Place name Gladstone, Manitoba returned for place_id 15b0997f0520713b.
# 741: place_id 07d9d9158d086000
# Request successful. Place name Taboo Golf Course returned for place_id 07d9d9158d086000.
# 742: place_id 07d9d2172b483001
# Request successful. Place name University of Toronto returned for place_id 07d9d2172b483001.
# 743: place_id 6fb3bc36a5af1cbe
# Request successful. Place name Indian Brook 14, Nova Scotia returned for place_id 6fb3bc36a5af1cbe.
# 744: place_id 1ff2873ba55f54d5
# Request successful. Place name Peachland, British Columbia returned for place_id 1ff2873ba55f54d5.
# 745: place_id 2acc596ea5ee275c
# Request successful. Place name Radisson, Saskatchewan returned for place_id 2acc596ea5ee275c.
# 746: place_id 37a5327a515eb3a2
# Request successful. Place name Starland County, Alberta returned for place_id 37a5327a515eb3a2.
# 747: place_id 68d5310a0771d6e2
# Request successful. Place name Vermilion, Alberta returned for place_id 68d5310a0771d6e2.
# 748: place_id 074d8e79c396c4ad
# Request successful. Place name Prince William, New Brunswick returned for place_id 074d8e79c396c4ad.
# 749: place_id 1cd044459319dfaa
# Request successful. Place name Zorra, Ontario returned for place_id 1cd044459319dfaa.
# 750: place_id 46d1d30a65765c0e
# Request successful. Place name Ross River, Yukon returned for place_id 46d1d30a65765c0e.
# 751: place_id 6fa6d7e43ef90629
# Request successful. Place name Gesgapegiag, Québec returned for place_id 6fa6d7e43ef90629.
# 752: place_id 68a83bac906e9fbd
# Request successful. Place name Lake Johnston No. 102, Saskatchewan returned for place_id 68a83bac906e9fbd.
# 753: place_id 76ba52ea58e07c8b
# Request successful. Place name Lot 15, Prince Edward Island returned for place_id 76ba52ea58e07c8b.
# 754: place_id 42a886dc73172b81
# Request successful. Place name Lot 49, Prince Edward Island returned for place_id 42a886dc73172b81.
# 755: place_id 0f8af43d9bdcb234
# Request successful. Place name Sussex Corner, New Brunswick returned for place_id 0f8af43d9bdcb234.
# 756: place_id 7d23e466f5c7f234
# Request successful. Place name Arviat, Nunavut returned for place_id 7d23e466f5c7f234.
# 757: place_id 07d9df8756088000
# Request successful. Place name Blue River returned for place_id 07d9df8756088000.
# 758: place_id 7d3e72c8b903728d
# Request successful. Place name Cavan-Monaghan, Ontario returned for place_id 7d3e72c8b903728d.
# 759: place_id 10c15de5749f5c37
# Request successful. Place name Seguin, Ontario returned for place_id 10c15de5749f5c37.
# 760: place_id 07d9cf85ea880000
# Request successful. Place name Tiffany Village Retirement Centre returned for place_id 07d9cf85ea880000.
# 761: place_id 4925600cde897992
# Request successful. Place name Revelstoke, British Columbia returned for place_id 4925600cde897992.
# 762: place_id 2a2e7406f1e6b812
# Request successful. Place name Penticton 1, British Columbia returned for place_id 2a2e7406f1e6b812.
# 763: place_id 5a8038f43b4e23ac
# Request successful. Place name North Glengarry, Ontario returned for place_id 5a8038f43b4e23ac.
# 764: place_id 3532117833019399
# Request successful. Place name Ritchot, Manitoba returned for place_id 3532117833019399.
# 765: place_id 07d9ed044e888002
# Request successful. Place name Huron Park Rec Centre returned for place_id 07d9ed044e888002.
# 766: place_id 6a26c50f69b20662
# Request successful. Place name Greater Madawaska, Ontario returned for place_id 6a26c50f69b20662.
# 767: place_id 07d9e5939d088001
# Request successful. Place name Vaughan, Ontario returned for place_id 07d9e5939d088001.
# 768: place_id 380da680e6026433
# Request successful. Place name Blackfalds, Alberta returned for place_id 380da680e6026433.
# 769: place_id 5fe73f279a93ed34
# Request successful. Place name L'Île-Perrot, Québec returned for place_id 5fe73f279a93ed34.
# 770: place_id 55a0e6afc2d36e71
# Request successful. Place name Maple Creek No. 111, Saskatchewan returned for place_id 55a0e6afc2d36e71.
# 771: place_id 61c185fd041c0edd
# Request successful. Place name Kearney, Ontario returned for place_id 61c185fd041c0edd.
# 772: place_id 0956d87577ee6449
# Request successful. Place name St. George's, Newfoundland and Labrador returned for place_id 0956d87577ee6449.
# 773: place_id 4168defdb4816696
# Request successful. Place name Athens, Ontario returned for place_id 4168defdb4816696.
# 774: place_id 07d9dd23af088002
# Request successful. Place name Dorset Park Community Hub returned for place_id 07d9dd23af088002.
# 775: place_id 248b67491ed768f5
# Request successful. Place name Colchester, Subd. A, Nova Scotia returned for place_id 248b67491ed768f5.
# 776: place_id 0934ac08a33478e5
# Request successful. Place name Bonnyville, Alberta returned for place_id 0934ac08a33478e5.
# 777: place_id 4736500c3d9c36ce
# Request successful. Place name Stone Mills, Ontario returned for place_id 4736500c3d9c36ce.
# 778: place_id 1e9df219262be97a
# Request successful. Place name Pasadena, Newfoundland and Labrador returned for place_id 1e9df219262be97a.
# 779: place_id 267ac55247fab9fb
# Request successful. Place name Gananoque, Ontario returned for place_id 267ac55247fab9fb.
# 780: place_id 07d9f42a76c81000
# Request successful. Place name Scarborough, Ontario returned for place_id 07d9f42a76c81000.
# 781: place_id 4af514470b719957
# Request successful. Place name Southwold, Ontario returned for place_id 4af514470b719957.
# 782: place_id 69879ec6f2d8a70b
# Request successful. Place name Shaunavon, Saskatchewan returned for place_id 69879ec6f2d8a70b.
# 783: place_id 07d9c93d96c84001
# Request successful. Place name Toronto City Hall returned for place_id 07d9c93d96c84001.
# 784: place_id 5da458e3cf26575f
# Request successful. Place name Neebing, Ontario returned for place_id 5da458e3cf26575f.
# 785: place_id 532e560e91db4fa8
# Request successful. Place name Neepawa, Manitoba returned for place_id 532e560e91db4fa8.
# 786: place_id 1e703ea8eb53568b
# Request successful. Place name Nanaimo A, British Columbia returned for place_id 1e703ea8eb53568b.
# 787: place_id 48084e2e8931edea
# Request successful. Place name Chase, British Columbia returned for place_id 48084e2e8931edea.
# 788: place_id 07d9db0f2a482001
# Request successful. Place name SFU Morris J Wosk Centre for Dialogue returned for place_id 07d9db0f2a482001.
# 789: place_id 3c2eaea5dcf0ae3d
# Request successful. Place name Lorraine, Québec returned for place_id 3c2eaea5dcf0ae3d.
# 790: place_id 0a6475066c161000
# Request successful. Place name Niagara College - Welland Campus returned for place_id 0a6475066c161000.
# 791: place_id 6902ec4ac97c3f85
# Request successful. Place name Chambly, Québec returned for place_id 6902ec4ac97c3f85.
# 792: place_id 4eecc706b1144bb9
# Request successful. Place name Oromocto, New Brunswick returned for place_id 4eecc706b1144bb9.
# 793: place_id 327b6738dbc4853b
# Request successful. Place name Cochrane, Unorganized, North Part, Ontario returned for place_id 327b6738dbc4853b.
# 794: place_id 686848fab706829b
# Request successful. Place name Beckwith, Ontario returned for place_id 686848fab706829b.
# 795: place_id 41b8de256b70c68e
# Request successful. Place name Les Cèdres, Québec returned for place_id 41b8de256b70c68e.
# 796: place_id 3a8c865e16024fa9
# Request successful. Place name Regina Beach, Saskatchewan returned for place_id 3a8c865e16024fa9.
# 797: place_id 4d40f539927417b8
# Request successful. Place name Lamont County, Alberta returned for place_id 4d40f539927417b8.
# 798: place_id 64e5d3e2b438ac41
# Request successful. Place name Havelock-Belmont-Methuen, Ontario returned for place_id 64e5d3e2b438ac41.
# 799: place_id 07d9db0deb080001
# Request successful. Place name Sheraton Parkway Toronto North Hotel & Suites returned for place_id 07d9db0deb080001.
# 800: place_id 0c2e522ec657a000
# Request successful. Place name Trillium Park returned for place_id 0c2e522ec657a000.
# 100 requests limit reached. Sleeping for 15 minutes...

# %%
len(places['place_id'])
# Out:
# 2987

# %%
places_df = pd.DataFrame(places)
places_df
# Out:
#               place_id                   place_name
# 0     3797791ff9c0e4c6             Toronto, Ontario
# 1     38d5974e82ed1a6c              Ottawa, Ontario
# 2     53504716d445dcad             Calgary, Alberta
# 3     6a6d896ba1cb5dc4            Edmonton, Alberta
# 4     1e5cb4d0509db554  Vancouver, British Columbia
# ...                ...                          ...
# 2982  209726d85549d2d5
# 2983  2b283eb6bc155115
# 2984  73fe89382cabbe53
# 2985  532b2c07da89e14d
# 2986  07d9db50c2080001
#
# [2987 rows x 2 columns]

# %% [markdown]
# ### 2.1 Dealing with not found place_id's

# %%
not_found_ids = places_df[places_df['place_name'] == '']['place_id']
len(not_found_ids)
# Out:
# 84

# %%
not_found_places = {}
not_found_places['place_id'] = not_found_ids
not_found_places['place_name'] = []

request_counter = 0
for n, place_id in enumerate(not_found_ids):
    print(f'{n+1}: place_id {place_id}')
    not_found_places['place_name'].append(getLocation(place_id))
    request_counter += 1
# Out:
# 1: place_id 446dd74cab94bc2c
# Request successful. Place name North Bay, Ontario returned for place_id 446dd74cab94bc2c.
# 2: place_id 133e76c8ced7070d
# Request successful. Place name Frontenac Islands, Ontario returned for place_id 133e76c8ced7070d.
# 3: place_id 691faf928074005b
# Request successful. Place name Midland, Ontario returned for place_id 691faf928074005b.
# 4: place_id 3f767a84de8478c5
# Request successful. Place name East Kootenay F, British Columbia returned for place_id 3f767a84de8478c5.
# 5: place_id 7c09c2a06f095bcb
# Request successful. Place name Northern Bruce Peninsula, Ontario returned for place_id 7c09c2a06f095bcb.
# 6: place_id 07d9db0d5e482001
# Request successful. Place name Toronto Pearson International Airport (YYZ) returned for place_id 07d9db0d5e482001.
# 7: place_id 4334903d32077699
# Request successful. Place name Hudson, Québec returned for place_id 4334903d32077699.
# 8: place_id 49ebfff28bf5f231
# Request successful. Place name Rosthern, Saskatchewan returned for place_id 49ebfff28bf5f231.
# 9: place_id 4cfecb308c0d1cdb
# Request successful. Place name Lot 48, Prince Edward Island returned for place_id 4cfecb308c0d1cdb.
# 10: place_id 07d9ed415fc84001
# Request successful. Place name Terry Fox Athletic Facility returned for place_id 07d9ed415fc84001.
# 11: place_id 0a744d8895d71000
# Request successful. Place name JLabs returned for place_id 0a744d8895d71000.
# 12: place_id 0842ce6167771c3f
# Request successful. Place name Pincher Creek, Alberta returned for place_id 0842ce6167771c3f.
# 13: place_id 5d0c901921b53224
# Request successful. Place name Marquis No. 191, Saskatchewan returned for place_id 5d0c901921b53224.
# 14: place_id 0ebe77226a861623
# Request successful. Place name Richmond, Subd. A, Nova Scotia returned for place_id 0ebe77226a861623.
# 15: place_id c255600fd37b5747
# Request successful. Place name Division No. 16, Manitoba returned for place_id c255600fd37b5747.
# 16: place_id 07d9e386a7083001
# Request successful. Place name SFU Segal Graduate School of Business returned for place_id 07d9e386a7083001.
# 17: place_id 0fc3a2e761942000
# Request successful. Place name The Glenmore Inn & Convention Centre returned for place_id 0fc3a2e761942000.
# 18: place_id 6468b9f119afb7fe
# Request successful. Place name Greenview No. 16, Alberta returned for place_id 6468b9f119afb7fe.
# 19: place_id 5a7f54c62500f55f
# Request successful. Place name Petrolia, Ontario returned for place_id 5a7f54c62500f55f.
# 20: place_id 07d9c9a94b082001
# Request successful. Place name South Fletcher's Sportsplex returned for place_id 07d9c9a94b082001.
# 21: place_id 07d9c93594082000
# Request successful. Place name JCCGV returned for place_id 07d9c93594082000.
# 22: place_id 2627dc0ab27eb9f0
# Request successful. Place name Edam, Saskatchewan returned for place_id 2627dc0ab27eb9f0.
# 23: place_id 7669ece9a304665d
# Request successful. Place name Bulkley-Nechako G, British Columbia returned for place_id 7669ece9a304665d.
# 24: place_id 435178530e095c49
# Request successful. Place name Tofield, Alberta returned for place_id 435178530e095c49.
# 25: place_id 0a32fae1acd9745e
# Request successful. Place name Mistissini, Québec returned for place_id 0a32fae1acd9745e.
# 26: place_id 07d9f78ba3880004
# Request successful. Place name Calgary JCC returned for place_id 07d9f78ba3880004.
# 27: place_id 0b3ea0737289c12a
# Request successful. Place name New Credit (Part) 40A, Ontario returned for place_id 0b3ea0737289c12a.
# 28: place_id 0d7bc8c612651e57
# Request successful. Place name Ucluelet, British Columbia returned for place_id 0d7bc8c612651e57.
# 29: place_id 07d9e05e5c883000
# Request successful. Place name Gordon first nation returned for place_id 07d9e05e5c883000.
# 30: place_id 07d9ec2e3c484003
# Request successful. Place name Ottawa Conference and Event Centre returned for place_id 07d9ec2e3c484003.
# 31: place_id 07d9ecd2b2087002
# Request successful. Place name Andrew Haydon Park returned for place_id 07d9ecd2b2087002.
# 32: place_id 07d9e3984c486002
# Request successful. Place name Ralph Thornton Centre returned for place_id 07d9e3984c486002.
# 33: place_id 07d9f344f3485000
# Request successful. Place name Kiwassa returned for place_id 07d9f344f3485000.
# 34: place_id 07d9d25654481003
# Request successful. Place name Churchill Seniors Centre returned for place_id 07d9d25654481003.
# 35: place_id 07d9c97f37c81002
# Request successful. Place name Royal Tyrrell Museum of Paleontology returned for place_id 07d9c97f37c81002.
# 36: place_id 07d9dbc7b9481001
# Request successful. Place name Royal Canadian Legion returned for place_id 07d9dbc7b9481001.
# 37: place_id 07d9dd20c3c80000
# Request successful. Place name Frank McKechnie Library returned for place_id 07d9dd20c3c80000.
# 38: place_id 07d9e4b054885002
# Request successful. Place name Gate C34 returned for place_id 07d9e4b054885002.
# 39: place_id 0a6389605fd60000
# Request successful. Place name Government House returned for place_id 0a6389605fd60000.
# 40: place_id 07d9f31f65080000
# Request successful. Place name Science World at TELUS World of Science returned for place_id 07d9f31f65080000.
# 41: place_id 5bbbb114a657f4c2
# Request successful. Place name Agency 1, Ontario returned for place_id 5bbbb114a657f4c2.
# 42: place_id 0ecf02972614d003
# Request successful. Place name Northgate Lions Seniors Recreation Centre returned for place_id 0ecf02972614d003.
# 43: place_id 2f61948e588cfaad
# Request successful. Place name Digby, Nova Scotia returned for place_id 2f61948e588cfaad.
# 44: place_id 012d3f0e462cf683
# Request successful. Place name Deer Ridge, Calgary returned for place_id 012d3f0e462cf683.
# 45: place_id 07d9dd1147881001
# Request successful. Place name Florence Lake returned for place_id 07d9dd1147881001.
# 46: place_id 0a64b8590d578002
# Request successful. Place name Milton, Ontario returned for place_id 0a64b8590d578002.
# 47: place_id 3e9bcf3d90dec76e
# Request successful. Place name Tullymet No. 216, Saskatchewan returned for place_id 3e9bcf3d90dec76e.
# 48: place_id 07d9edb967c85001
# Request successful. Place name Clean Harbors returned for place_id 07d9edb967c85001.
# 49: place_id 07d9e4994f085000
# Request successful. Place name Hillel @ U of T returned for place_id 07d9e4994f085000.
# 50: place_id 0a35d0bc1cf619e9
# Request successful. Place name Greenstone, Ontario returned for place_id 0a35d0bc1cf619e9.
# 51: place_id 07d9ec8208881000
# Request successful. Place name PriceSmart Foods returned for place_id 07d9ec8208881000.
# 52: place_id 07d9e3b70b084001
# Request successful. Place name Fairbank Memorial Park returned for place_id 07d9e3b70b084001.
# 53: place_id 07d9d58dee885003
# Request successful. Place name West Vancouver School District returned for place_id 07d9d58dee885003.
# 54: place_id 07d9dbe404887002
# Request successful. Place name Caledon East Arena returned for place_id 07d9dbe404887002.
# 55: place_id 0164901d13a6ac10
# Request successful. Place name Little Portugal, Toronto returned for place_id 0164901d13a6ac10.
# 56: place_id 0a64a3cbb1d71000
# Request successful. Place name Carefirst seniors & community Services Association returned for place_id 0a64a3cbb1d71000.
# 57: place_id 05739ba82d048a83
# Request successful. Place name Melita, Manitoba returned for place_id 05739ba82d048a83.
# 58: place_id 07d9caf924482001
# Request successful. Place name West Lincoln Arena returned for place_id 07d9caf924482001.
# 59: place_id 07d9cb8c2ac81001
# Request successful. Place name Mount Royal University, EC returned for place_id 07d9cb8c2ac81001.
# 60: place_id 0fc3b6f1cd541001
# Request successful. Place name Woods Park Care Centre returned for place_id 0fc3b6f1cd541001.
# 61: place_id 07d9c9374e082001
# Request successful. Place name Handsworth Secondary School returned for place_id 07d9c9374e082001.
# 62: place_id 07d9f22e17887001
# Request successful. Place name Boyle Street Plaza returned for place_id 07d9f22e17887001.
# 63: place_id 4066d7e40f78c3e6
# Request successful. Place name Chippewas of the Thames First Nation 42, Ontario returned for place_id 4066d7e40f78c3e6.
# 64: place_id 07d9ec8411487001
# Request successful. Place name Saint John Free Public Library returned for place_id 07d9ec8411487001.
# 65: place_id 07d9d2e1b4c88002
# Request successful. Place name Frost Building returned for place_id 07d9d2e1b4c88002.
# 66: place_id 07fd834cc7962000
# Request successful. Place name UNIVERSAL EVENTSPACE - byPeterandPauls.com returned for place_id 07fd834cc7962000.
# 67: place_id 44d0a431abeb16cd
# Request successful. Place name Fraser Valley D, British Columbia returned for place_id 44d0a431abeb16cd.
# 68: place_id 07d9da1c1d082000
# Request successful. Place name Surrey Civic Hall returned for place_id 07d9da1c1d082000.
# 69: place_id 34bf82df7affbffd
# Request successful. Place name Fraser-Fort George F, British Columbia returned for place_id 34bf82df7affbffd.
# 70: place_id 0db85e58ef54d000
# Request successful. Place name Maskinonge returned for place_id 0db85e58ef54d000.
# 71: place_id 07d9e5b875083002
# Request successful. Place name Valleyview, AB returned for place_id 07d9e5b875083002.
# 72: place_id 727d6b3f05851a2c
# Request successful. Place name Red Sucker Lake 1976, Manitoba returned for place_id 727d6b3f05851a2c.
# 73: place_id 07d9ddb1ec488003
# Request successful. Place name Bannock Point Petroforms returned for place_id 07d9ddb1ec488003.
# 74: place_id 40046fbabb551f13
# Request successful. Place name Spirit River, Alberta returned for place_id 40046fbabb551f13.
# 75: place_id 07d9cccd0b484000
# Request successful. Place name MacDonald-Harrington Building returned for place_id 07d9cccd0b484000.
# 76: place_id 07d9db8934c88001
# Request successful. Place name Trillium Health Centre returned for place_id 07d9db8934c88001.
# 77: place_id 07d9d527dd485002
# Request successful. Place name Confederation Building returned for place_id 07d9d527dd485002.
# 78: place_id 29d1818371f2225d
# Request successful. Place name Cana No. 214, Saskatchewan returned for place_id 29d1818371f2225d.
# 79: place_id 07d9f3764bc88000
# Request successful. Place name Villa Elegance returned for place_id 07d9f3764bc88000.
# 80: place_id 209726d85549d2d5
# Request successful. Place name Memramcook, New Brunswick returned for place_id 209726d85549d2d5.
# 81: place_id 2b283eb6bc155115
# Request successful. Place name Machin, Ontario returned for place_id 2b283eb6bc155115.
# 82: place_id 73fe89382cabbe53
# Request successful. Place name McCartney's Flat 4, British Columbia returned for place_id 73fe89382cabbe53.
# 83: place_id 532b2c07da89e14d
# Request successful. Place name Grimshaw, Alberta returned for place_id 532b2c07da89e14d.
# 84: place_id 07d9db50c2080001
# Request successful. Place name Capital Region Housing Corporation returned for place_id 07d9db50c2080001.

# %%
not_found_places_df = pd.DataFrame(not_found_places)
not_found_places_df
# Out:
#               place_id                            place_name
# 120   446dd74cab94bc2c                    North Bay, Ontario
# 155   133e76c8ced7070d            Frontenac Islands, Ontario
# 241   691faf928074005b                      Midland, Ontario
# 362   3f767a84de8478c5     East Kootenay F, British Columbia
# 483   7c09c2a06f095bcb     Northern Bruce Peninsula, Ontario
# ...                ...                                   ...
# 2982  209726d85549d2d5             Memramcook, New Brunswick
# 2983  2b283eb6bc155115                       Machin, Ontario
# 2984  73fe89382cabbe53  McCartney's Flat 4, British Columbia
# 2985  532b2c07da89e14d                     Grimshaw, Alberta
# 2986  07d9db50c2080001    Capital Region Housing Corporation
#
# [84 rows x 2 columns]

# %%
for place_id, place_name in zip(not_found_places_df['place_id'], not_found_places_df['place_name']):
  places_df.loc[places_df['place_id'] == place_id, 'place_name'] = place_name

places_df
# Out:
#               place_id                            place_name
# 0     3797791ff9c0e4c6                      Toronto, Ontario
# 1     38d5974e82ed1a6c                       Ottawa, Ontario
# 2     53504716d445dcad                      Calgary, Alberta
# 3     6a6d896ba1cb5dc4                     Edmonton, Alberta
# 4     1e5cb4d0509db554           Vancouver, British Columbia
# ...                ...                                   ...
# 2982  209726d85549d2d5             Memramcook, New Brunswick
# 2983  2b283eb6bc155115                       Machin, Ontario
# 2984  73fe89382cabbe53  McCartney's Flat 4, British Columbia
# 2985  532b2c07da89e14d                     Grimshaw, Alberta
# 2986  07d9db50c2080001    Capital Region Housing Corporation
#
# [2987 rows x 2 columns]

# %%
for place_id, place_name in zip(places_df['place_id'], places_df['place_name']):
  tweets_df.loc[tweets_df['place_id'] == place_id, 'place_name'] = place_name

tweets_df
# Out:
#        Unnamed: 0                 date_time             tweet_id  \
# 0               0  2022-02-24T21:33:19.000Z  1496961461465542656
# 1               1  2022-02-24T20:28:33.000Z  1496945165365219333
# 2               2  2022-02-24T20:25:13.000Z  1496944326416510984
# 3               3  2022-02-24T19:44:18.000Z  1496934029542793224
# 4               4  2022-02-24T18:53:50.000Z  1496921328103804935
# ...           ...                       ...                  ...
# 57134       57134  2018-01-01T14:36:44.000Z   947839007450308608
# 57135       57135  2018-01-01T06:29:56.000Z   947716501452177408
# 57136       57136  2018-01-01T05:29:42.000Z   947701343443091456
# 57137       57137  2018-01-01T03:08:09.000Z   947665721349279745
# 57138       57138  2018-01-01T00:08:23.000Z   947620481288495106
#
#                  author_id          place_id  \
# 0               3240659214  38d5974e82ed1a6c
# 1      1469167464101515267  0811cf61cd9ea52f
# 2               3355188729  3797791ff9c0e4c6
# 3                 21305650  3797791ff9c0e4c6
# 4                 50382485  71bdc845bc7609c7
# ...                    ...               ...
# 57134   777511588701937665  13e80e6f3ac67066
# 57135           3164684096  53504716d445dcad
# 57136             28465428  626695e48d21858b
# 57137             26161882  5d058f2e9fe1516c
# 57138            415558897  3797791ff9c0e4c6
#
#                                               tweet_text  \
# 0      @JosephConwell7 @Reuters I live here &amp; the...
# 1      Winnipeg seniors, wya?!! \nI’m doing Mini sess...
# 2      This is no joke. I have gone to several stores...
# 3      @cllrainslie Vaccines are great for the elderl...
# 4      Be part of the movement from hallway care to h...
# ...                                                  ...
# 57134  @mheavyhead I lived in India for 4 months and ...
# 57135  @CMcKerracher @themadsloth Refugees get nowher...
# 57136           “Old women find me attractive.”\n-not me
# 57137  (I forgot to do this for 2016.)\n\nMy favourit...
# 57138  Please check in on any elderly neighbours. #se...
#
#                                             cleaned_text  \
# 0      I live here and these far right bully boys pic...
# 1      Winnipeg seniors, wya?!! Im doing Mini session...
# 2      This is no joke. I have gone to several stores...
# 3      Vaccines are great for the elderly and / or th...
# 4      Be part of the movement from hallway care to h...
# ...                                                  ...
# 57134  I lived in India for 4 months and the amount o...
# 57135  Refugees get nowhere close to that. That lies ...
# 57136              Old women find me attractive. -not me
# 57137  (I forgot to do this for 2016.) My favourite 2...
# 57138  Please check in on any elderly neighbours. sen...
#
#                                     hashtags                     place_name
# 0                                         []                Ottawa, Ontario
# 1                ['winnipeg', 'collegegrad']             Winnipeg, Manitoba
# 2                                         []               Toronto, Ontario
# 3                                         []               Toronto, Ontario
# 4                ['Woodstock', 'Healthcare']             Woodstock, Ontario
# ...                                      ...                            ...
# 57134                                     []  Maple Ridge, British Columbia
# 57135                                     []               Calgary, Alberta
# 57136                                     []              Brandon, Manitoba
# 57137                                     []           Halifax, Nova Scotia
# 57138  ['seniors', 'neighbours', 'staysafe']               Toronto, Ontario
#
# [57139 rows x 9 columns]

# %%
import re

for tweet_id, place in zip(tweets_df['tweet_id'], tweets_df['place_name']):
  tweets_df.loc[tweets_df['tweet_id'] == tweet_id, 'region'] = re.search('[^,]*$', place).group(0).strip()

# %%
reordered_columns = ['tweet_id', 'date_time', 'author_id', 'place_id', 'place_name', 'region', 'tweet_text', 'cleaned_text', 'hashtags']
tweets_df = tweets_df[reordered_columns]
tweets_df
# Out:
#                   tweet_id                 date_time            author_id  \
# 0      1496961461465542656  2022-02-24T21:33:19.000Z           3240659214
# 1      1496945165365219333  2022-02-24T20:28:33.000Z  1469167464101515267
# 2      1496944326416510984  2022-02-24T20:25:13.000Z           3355188729
# 3      1496934029542793224  2022-02-24T19:44:18.000Z             21305650
# 4      1496921328103804935  2022-02-24T18:53:50.000Z             50382485
# ...                    ...                       ...                  ...
# 57134   947839007450308608  2018-01-01T14:36:44.000Z   777511588701937665
# 57135   947716501452177408  2018-01-01T06:29:56.000Z           3164684096
# 57136   947701343443091456  2018-01-01T05:29:42.000Z             28465428
# 57137   947665721349279745  2018-01-01T03:08:09.000Z             26161882
# 57138   947620481288495106  2018-01-01T00:08:23.000Z            415558897
#
#                place_id                     place_name            region  \
# 0      38d5974e82ed1a6c                Ottawa, Ontario           Ontario
# 1      0811cf61cd9ea52f             Winnipeg, Manitoba          Manitoba
# 2      3797791ff9c0e4c6               Toronto, Ontario           Ontario
# 3      3797791ff9c0e4c6               Toronto, Ontario           Ontario
# 4      71bdc845bc7609c7             Woodstock, Ontario           Ontario
# ...                 ...                            ...               ...
# 57134  13e80e6f3ac67066  Maple Ridge, British Columbia  British Columbia
# 57135  53504716d445dcad               Calgary, Alberta           Alberta
# 57136  626695e48d21858b              Brandon, Manitoba          Manitoba
# 57137  5d058f2e9fe1516c           Halifax, Nova Scotia       Nova Scotia
# 57138  3797791ff9c0e4c6               Toronto, Ontario           Ontario
#
#                                               tweet_text  \
# 0      @JosephConwell7 @Reuters I live here &amp; the...
# 1      Winnipeg seniors, wya?!! \nI’m doing Mini sess...
# 2      This is no joke. I have gone to several stores...
# 3      @cllrainslie Vaccines are great for the elderl...
# 4      Be part of the movement from hallway care to h...
# ...                                                  ...
# 57134  @mheavyhead I lived in India for 4 months and ...
# 57135  @CMcKerracher @themadsloth Refugees get nowher...
# 57136           “Old women find me attractive.”\n-not me
# 57137  (I forgot to do this for 2016.)\n\nMy favourit...
# 57138  Please check in on any elderly neighbours. #se...
#
#                                             cleaned_text  \
# 0      I live here and these far right bully boys pic...
# 1      Winnipeg seniors, wya?!! Im doing Mini session...
# 2      This is no joke. I have gone to several stores...
# 3      Vaccines are great for the elderly and / or th...
# 4      Be part of the movement from hallway care to h...
# ...                                                  ...
# 57134  I lived in India for 4 months and the amount o...
# 57135  Refugees get nowhere close to that. That lies ...
# 57136              Old women find me attractive. -not me
# 57137  (I forgot to do this for 2016.) My favourite 2...
# 57138  Please check in on any elderly neighbours. sen...
#
#                                     hashtags
# 0                                         []
# 1                ['winnipeg', 'collegegrad']
# 2                                         []
# 3                                         []
# 4                ['Woodstock', 'Healthcare']
# ...                                      ...
# 57134                                     []
# 57135                                     []
# 57136                                     []
# 57137                                     []
# 57138  ['seniors', 'neighbours', 'staysafe']
#
# [57139 rows x 9 columns]

# %%
tweets_df['region'].value_counts()[:11]
# Out:
# Ontario                      27150
# British Columbia              9161
# Alberta                       8178
# Québec                        2105
# Manitoba                      2053
# Nova Scotia                   2004
# Saskatchewan                  1476
# Newfoundland and Labrador     1001
# New Brunswick                  795
# Canada                         356
# Prince Edward Island           291
# Name: region, dtype: int64

# %%
tweets_df.to_csv('cleaned_elderly_tweets.csv')

# %% [markdown]
# ### 3. Exporting to json format for Labelbox labeling

# %%
labelbox_test = tweets_df[:10]

# %%
labelbox_test
# Out:
#    Unnamed: 0                 date_time             tweet_id  \
# 0           0  2022-02-24T21:33:19.000Z  1496961461465542656
# 1           1  2022-02-24T20:28:33.000Z  1496945165365219333
# 2           2  2022-02-24T20:25:13.000Z  1496944326416510984
# 3           3  2022-02-24T19:44:18.000Z  1496934029542793224
# 4           4  2022-02-24T18:53:50.000Z  1496921328103804935
# 5           5  2022-02-24T15:10:38.000Z  1496865157967925268
# 6           6  2022-02-24T14:25:12.000Z  1496853721283797002
# 7           7  2022-02-24T14:19:46.000Z  1496852357539418116
# 8           8  2022-02-24T13:46:04.000Z  1496843876916727809
# 9           9  2022-02-24T03:54:06.000Z  1496694903690174467
#
#              author_id          place_id  \
# 0           3240659214  38d5974e82ed1a6c
# 1  1469167464101515267  0811cf61cd9ea52f
# 2           3355188729  3797791ff9c0e4c6
# 3             21305650  3797791ff9c0e4c6
# 4             50382485  71bdc845bc7609c7
# 5           3130104741  5f102b4a7cc3d42e
# 6            633402666  5c43cbdfce4d3247
# 7  1012293706077138944  4a0cd47b60820d6f
# 8   770021584681701379  701b7d92002f366d
# 9           2151994626  3797791ff9c0e4c6
#
#                                           tweet_text  \
# 0  @JosephConwell7 @Reuters I live here &amp; the...
# 1  Winnipeg seniors, wya?!! \nI’m doing Mini sess...
# 2  This is no joke. I have gone to several stores...
# 3  @cllrainslie Vaccines are great for the elderl...
# 4  Be part of the movement from hallway care to h...
# 5  @msemilyrushton @CTVNews Old men start wars yp...
# 6                 God save us from old men in suits.
# 7  Not impressed with Nova Scotia’s reopening pla...
# 8  @Kalandras_ In a recent one shot, two characte...
# 9  @oldpappy59 @FrankKhalidUK During the peak of ...
#
#                                         cleaned_text
# 0  i live here amp these far right bully boys pic...
# 1  winnipeg seniors wya im doing mini sessions st...
# 2  this is no joke i have gone to several stores ...
# 3  vaccines are great for the elderly and  or the...
# 4  be part of the movement from hallway care to h...
# 5         old men start wars ypung people fight them
# 6                  god save us from old men in suits
# 7  not impressed with nova scotias reopening plan...
# 8  in a recent one shot two characters were grump...
# 9  during the peak of the pandemic roman bought a...

# %%
labelbox_dict = {}
labelbox_dict['data'] = list(labelbox_test.iloc[:, -1])
labelbox_dict['externalId'] = 'tweets.txt'
labelbox_dict
# Out:
# {'data': ['i live here amp these far right bully boys picked on poor elderly amp vulnerable consistently punching down like cowards stealing food from homeless abusing residents of women amp street youth shelters threatening to sexually assault girls smashing windows of lgbqt families',
#   'winnipeg seniors wya im doing mini sessions starting march dm me to shoot winnipeg collegegrad',
#   'this is no joke i have gone to several stores today to try and buy incontinence products the shelves are almost empty amazon deliveries dates are lengthy is this supply chains truckers blocking the borders or what why must the elderly and disabled suffer humiliation',
#   'vaccines are great for the elderly and  or the sick',
#   'be part of the movement from hallway care to home care help our aging population age well at home seeking allied health manager in woodstock on healthcare',
#   'old men start wars ypung people fight them',
#   'god save us from old men in suits',
#   'not impressed with nova scotias reopening plan phase 1 seems reasonable but i think the other phases are rushed particularly phase 3 very concerned about elderly and those with health conditions 11 nspoli',
#   'in a recent one shot two characters were grumpy old men and it was the actual best',
#   'during the peak of the pandemic roman bought all the hotel rooms nearby stamford bridge for several months for the exclusive use of nhs doctors and nurses  the club donated thousands of meals to the elderly and needy did that get mentioned in parliament  no '],
#  'externalId': 'tweets.txt'}

# %%
import json

with open('labelbox_test.json', 'w') as outfile:
  json.dump(labelbox_dict, outfile)
